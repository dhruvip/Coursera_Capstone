# %% [markdown]
# **Loading libraries**

# %%
#https://www.worldatlas.com/articles/the-most-visited-states-in-the-us.html
#https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_area
#https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population
# https://stats.stackexchange.com/questions/174383/how-to-predict-outcome-with-only-positive-cases-as-trai/n/ing
# https://www.google.com/search?q=what+happens+when+a+classification+model+is+trained+only+on+positive+cases+site:stats.stackexchange.com&client=ubuntu&channel=fs&sa=X&ved=2ahUKEwiCn82O2qXiAhUkSo8KHXRBAfcQrQIoBDAKegQIAxAM&biw=1311&bih=673
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup 
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
# from FourSquareAPI import FourSquareAPI
import folium 
from IPython.display import Image 
from IPython.core.display import HTML 
import matplotlib.cm as cm
import matplotlib.colors as colors

# %matplotlib inline 
mpl.style.use('ggplot')

class FourSquareAPI():
    def __init__(self, client_id, client_secret, version='20180604', limit=30):
        self.client_id = client_id
        self.client_secret = client_secret
        self.version = version
        self.limit = limit
        
    def get_venue_search(self, latitude, longitude, search_query, radius=500):
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.\
format(self.client_id, self.client_secret, latitude, longitude, self.version, search_query, radius, self.limit)
        results = requests.get(url).json()
        print(results)
        venues = results['response']['venues']
        if not len(venues):
            dataframe_filtered = 'No Venues Available'
        else:
            df = json_normalize(venues)
            # keep only columns that include venue name, and anything that is associated with location
            filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
            dataframe_filtered = df.loc[:, filtered_columns]

            # function that extracts the category of the venue
            def get_category_type(row):
                try:
                    categories_list = row['categories']
                except:
                    categories_list = row['venue.categories']

                if len(categories_list) == 0:
                    return None
                else:
                    return categories_list[0]['name']

            # filter the category for each row
            dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
            dataframe_filtered['search_q'] = search_query
            # clean column names by keeping only last term
            dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

        return dataframe_filtered
    
    def get_trending_places(self, latitude, longitude):
        url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.\
        format(self.client_id, self.client_secret, latitude, longitude, self.version)
        results = requests.get(url).json()
        if len(results['response']['venues']) == 0:
            trending_venues_df = 'No trending venues are available at the moment!'
        else:
            trending_venues = results['response']['venues']
            trending_venues_df = json_normalize(trending_venues)
            columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
            trending_venues_df = trending_venues_df.loc[:, columns_filtered]
            trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
        return trending_venues_df
fsq = FourSquareAPI('QRTP4LWZZWCQEVRBNPS0P4D1W33WZZ4YMSYDZXJ0NISIL3JI','NVKCW0IHZFGE340QPJGVG2AX1C1DZ2V3QKNVGCZYTWI4TNIK')

# %% [markdown]
# **Reading data files**

# %%
df1 = pd.read_csv('fast-food-restaurants/Datafiniti_Fast_Food_Restaurants.csv')
df2 = pd.read_csv('fast-food-restaurants/FastFoodRestaurants.csv')

# %% [markdown]
# **Cleaning data and saving it to a csv file**

# %%
df1 = df1[['address','categories','city','country','latitude','longitude','name','postalCode','province']]
df2 = df2[['address','city','country','latitude','longitude','name','postalCode','province']]
df = pd.concat([df1,df2], ignore_index=True)
df.sort_values(by='name',inplace=True)
df_split =  list()
for index, each_ in df.iterrows():
    name = each_['name'].split('/')
    if len(name) > 1:
        each_['name'] = name[0]
        new_ = each_.copy()
        new_['name'] = name[1]
        if not len(df_split):
            df_split = each_.values
        else: 
            df_split = np.vstack((df_split, each_.values))
        df_split = np.vstack((df_split, new_.values))        
    else:      
        if not len(df_split):
            df_split = each_.values
        else: 
            df_split = np.vstack((df_split, each_.values))

df_split = pd.DataFrame(df_split, columns=df.columns)
df_split['cleaned_name'] = df_split['name'].copy()
def strip_sp_charac(x):
    x['cleaned_name'] = ''.join(e for e in x['cleaned_name'] if e.isalnum())
    x['cleaned_name'] = x['cleaned_name'].lower()
    return x
df_split = df_split.apply(strip_sp_charac, axis=1)
df_split = df_split.drop_duplicates(['latitude','longitude','name'],keep='last')
df_split.to_csv('fast-food-restaurants/cleaned-data-all.csv')

# %% [markdown]
# **Reading cleaned data from csv file**

# %%
df_split= pd.read_csv('fast-food-restaurants/cleaned-data-all.csv')

# %%
df_grp_by = df_split.groupby('cleaned_name', as_index=False)
(df_grp_by.size()).sort_values(ascending=True, inplace=True)
df_agg = df_grp_by.count().sort_values('address')
df_top100_list = df_agg[df_agg['address']>100]['cleaned_name'].values

# %% [markdown]
# **DataFrame of restaurant with more than 100 outlets all over US**

# %%
df_top100 = df_split.loc[df_split['cleaned_name'].isin(df_top100_list)]
df_top100.drop('Unnamed: 0',axis=1, inplace=True)
df_top100.head()
# Out:
# /home/dhruvi/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                 address categories          city country   latitude  \
# 69      1027 Ne Rice Rd        NaN   Lees Summit      US  38.931200
# 70       717 S Bluff St        NaN  Saint George      US  37.096080
# 71  3200 W Mercury Blvd  Fast Food       Hampton      US  37.033187
# 72       2489 S Main St        NaN     Bountiful      US  40.862630
# 73        109 Market Dr  Fast Food       Emporia      US  36.703902
#
#      longitude    name postalCode province cleaned_name
# 69  -94.358900  Arby's      64086       MO        arbys
# 70 -113.586490  Arby's      84770       UT        arbys
# 71  -76.417821  Arby's      23666       VA        arbys
# 72 -111.895090  Arby's      84010       UT        arbys
# 73  -77.541463  Arby's      23847       VA        arbys

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 9
df_top100.groupby('cleaned_name')['province'].count().plot(
    kind='bar',
    label='# Outlets',
    y='province',
    x='count'
)
plt.title('Number of Outlets per franchise in USA')
plt.ylabel('# Outlets')
plt.xlabel('Franchise')

# %% [markdown]
# **Province in Top 75% of the Fast Food Restaurant distribution**

# %%
df_plot = df_top100.groupby('province')['name'].count()
province_75q = df_top100.groupby('province')['name'].count().quantile(0.75)
x = df_plot.index
top25_list = df_plot[df_plot > province_75q].index.values

# %%
fig,ax = plt.subplots()
df_plot.plot(kind='bar',ax=ax, label='Province')
ax.plot(x,[province_75q]*len(x), label='75% percentile', linestyle='--')
legend = ax.legend(loc='upper right')
plt.title('Number of Fast Food restaurants per Province')
plt.xlabel('Province')
plt.ylabel('# Count')
plt.show()
print('Provinces which lie in the top 25% of the restaurant distribution are: ', \
      top25_list)

# %%
df_top25 = df_top100.loc[df_top100['province'].isin(top25_list)]
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 12
fig_size[1] = 9
colors = ['red','blue','lightgreen','darkgreen','purple','yellow','orange','violet','lightblue',\
          'black','grey','brown','pink']

# %%
df_top25.groupby('province').count().plot(kind='pie',y='address',label='Province', colors=colors)
plt.title('Distribution within the top 25% province')

# %% [markdown]
# **Creating a meta data dataframe for provinces**

# %%
#most_visited_list = ['CA','FL','NV','TX','NY','VA','SC','AZ','GA','HI']
df_province = pd.read_csv('province_meta_data.csv')
df_province['rest_per_km2'] = df_province['restaurants_in_province']/df_province['area_km2']
df_province['rest_per_1000people'] = df_province['restaurants_in_province']/df_province['population'] * 1000
df_province
# Out:
#     Unnamed: 0  area_km2  population province  is_tourist  \
# 0            0    403466    39557045       CA           1
# 1            1    138887    21299325       FL           1
# 2            2    148959    10519475       GA           1
# 3            3    143793    12741080       IL           0
# 4            4     92789     6691878       IN           0
# 5            5    146435     9995915       MI           0
# 6            6    125920    10383620       NC           0
# 7            7    122057    19542209       NY           1
# 8            8    105829    11689442       OH           0
# 9            9    115883    12807060       PA           0
# 10          10    106798     6770010       TN           0
# 11          11    676587    28701845       TX           1
# 12          12    102279     8517685       VA           1
#
#     restaurants_in_province  rest_per_km2  rest_per_1000people
# 0                      1337      0.003314             0.033799
# 1                       874      0.006293             0.041034
# 2                       636      0.004270             0.060459
# 3                       571      0.003971             0.044816
# 4                       502      0.005410             0.075016
# 5                       507      0.003462             0.050721
# 6                       561      0.004455             0.054027
# 7                       488      0.003998             0.024972
# 8                       821      0.007758             0.070234
# 9                       521      0.004496             0.040681
# 10                      452      0.004232             0.066765
# 11                     1104      0.001632             0.038464
# 12                      501      0.004898             0.058819

# %%
df_top25 = pd.merge(df_top25, df_province, on='province',how='left')
df_top25.drop(['Unnamed: 0','area_km2','population', 'restaurants_in_province'], axis=1, inplace=True)
df_top25.head()
# Out:
#                 address             categories             city country  \
# 0   3200 W Mercury Blvd              Fast Food          Hampton      US
# 1         109 Market Dr              Fast Food          Emporia      US
# 2  1700 Timberwood Blvd  Fast Food Restaurants  Charlottesville      US
# 3         193 Grant Ave   Fast Food Restaurant           Auburn      US
# 4        2255 Us Hwy 27                    NaN         Clermont      US
#
#     latitude  longitude    name postalCode province cleaned_name  is_tourist  \
# 0  37.033187 -76.417821  Arby's      23666       VA        arbys           1
# 1  36.703902 -77.541463  Arby's      23847       VA        arbys           1
# 2  38.129807 -78.437118  Arby's      22911       VA        arbys           1
# 3  42.948394 -76.548617  Arby's      13021       NY        arbys           1
# 4  28.539043 -81.738181  Arby's      34711       FL        arbys           1
#
#    rest_per_km2  rest_per_1000people
# 0      0.004898             0.058819
# 1      0.004898             0.058819
# 2      0.004898             0.058819
# 3      0.003998             0.024972
# 4      0.006293             0.041034

# %%
df_top25.rename({'is_tourist':'is_tourist_province',
                'rest_per_km2': 'rest_per_km2_province',
                'rest_per_1000people':'rest_per_1000people_province'}, axis=1,inplace=True)
df_top25.head()
# Out:
#                 address             categories             city country  \
# 0   3200 W Mercury Blvd              Fast Food          Hampton      US
# 1         109 Market Dr              Fast Food          Emporia      US
# 2  1700 Timberwood Blvd  Fast Food Restaurants  Charlottesville      US
# 3         193 Grant Ave   Fast Food Restaurant           Auburn      US
# 4        2255 Us Hwy 27                    NaN         Clermont      US
#
#     latitude  longitude    name postalCode province cleaned_name  \
# 0  37.033187 -76.417821  Arby's      23666       VA        arbys
# 1  36.703902 -77.541463  Arby's      23847       VA        arbys
# 2  38.129807 -78.437118  Arby's      22911       VA        arbys
# 3  42.948394 -76.548617  Arby's      13021       NY        arbys
# 4  28.539043 -81.738181  Arby's      34711       FL        arbys
#
#    is_tourist_province  rest_per_km2_province  rest_per_1000people_province
# 0                    1               0.004898                      0.058819
# 1                    1               0.004898                      0.058819
# 2                    1               0.004898                      0.058819
# 3                    1               0.003998                      0.024972
# 4                    1               0.006293                      0.041034

# %%
df_top25.sort_values(ascending=True, by='province',inplace=True)
df_top25_grpby = df_top25.groupby('province')
# df_top25.set_index(['province', 'cleaned_name'], inplace=True)

# %% [markdown]
# **Exploring for ILLINOIS**

# %%
df_il = df_top25_grpby.get_group('IL')
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans , DBSCAN

X = df_top25[['latitude','longitude']].values
Clus_dataSet = StandardScaler().fit_transform(X)
clusterNum = 4
# k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
# k_means.fit(X)
# labels = k_means.labels_

epsilon = 0.3
minimumSamples = 7
db = DBSCAN(eps=epsilon, min_samples=minimumSamples).fit(X)
labels = db.labels_

df_top25['labels'] = labels

# %%
df_top25.head()

# %%
from IPython.display import Image 
from IPython.core.display import HTML 
import random

number_of_colors = len(labels)

colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]

usmap = folium.Map(location=[41.5277,-88.0723], zoom_start=11) 


# for name, group in df_top25_grpby:
for index, each_ in df_top25.iterrows():
    popup=folium.Popup(each_['name'], parse_html=True)
    if each_['labels'] < 0 :
        continue
    folium.features.CircleMarker(
        [each_['latitude'], each_['longitude']],
        radius=2,
        color=colors[each_['labels']],
        popup= popup,
        fill = True,
        fill_color = colors[each_['labels']],
        fill_opacity = 0.6
    ).add_to(usmap)
usmap

# %%
df_il.shape
# Out:
# (571, 13)

# %%
usmap.save('top25.html')

# %% [markdown]
# **Further calculation**

# %%
def add_lat_long(lat_long, values):
    if type(lat_long) is not np.ndarray:
        lat_long = values
    else:
        lat_long = np.vstack((lat_long,values))
    return lat_long

def get_neighbours(each_):
    lat_long = None
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'school')
    if not (type(each_venue) is str):
        each_['schools'] = len(each_venue.index)
        lat_long = each_venue[['lat','lng']].values
    else:
        each_['schools'] = 0
        
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'university')
    if not (type(each_venue) is str):
        each_['university'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['university'] = 0
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'hospital')
    if not (type(each_venue) is str):
        each_['hospital'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['hospital'] = 0
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'park')
    if not (type(each_venue) is str):
        each_['park'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['park'] = 0
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'office')
    if not (type(each_venue) is str):
        each_['offices'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['offices'] = 0
    
        
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'mall')
    if not (type(each_venue) is str):
        each_['mall'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['mall'] = 0

    each_['ammenities_lat_long'] = lat_long
    return each_ 

df_il.reset_index()
df_il = df_il.apply(get_neighbours,axis=1)
# Out:
# {'meta': {'code': 200, 'requestId': '5ce147d0351e3d1288bbf5aa'}, 'response': {'venues': [{'name': 'Joliet Central High School', 'categories': [{'name': 'High School', 'shortName': 'High School', 'primary': True, 'pluralName': 'High Schools', 'id': '4bf58dd8d48988d13d941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4b7aba4ef964a5207f392fe3', 'location': {'address': '201 E Jefferson St', 'lng': -88.07414222612097, 'city': 'Joliet', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['201 E Jefferson St', 'Joliet, IL 60432', 'United States'], 'distance': 215, 'lat': 41.52633799122486, 'postalCode': '60432', 'labeledLatLngs': [{'lng': -88.07414222612097, 'lat': 41.52633799122486, 'label': 'display'}]}, 'referralId': 'v-1558267856'}, {'name': 'Jolet Central High School Little Theater', 'categories': [{'name': 'Performing Arts Venue', 'shortName': 'Performing Arts', 'primary': True, 'pluralName': 'Performing Arts Venues', 'id': '4bf58dd8d48988d1f2931735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '5088190de4b0fa42fce3bca1', 'location': {'lng': -88.073713, 'city': 'Joliet', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Joliet, IL 60432', 'United States'], 'distance': 270, 'lat': 41.525492, 'postalCode': '60432', 'labeledLatLngs': [{'lng': -88.073713, 'lat': 41.525492, 'label': 'display'}]}, 'referralId': 'v-1558267856'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147d04c1f6753b772c2f1'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147d19fb6b77580512a64'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147d3f594df57ec809679'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147d4351e3d1288bc0d45'}, 'response': {'venues': [{'name': 'Link Office', 'categories': [{'name': 'Government Building', 'shortName': 'Government', 'primary': True, 'pluralName': 'Government Buildings', 'id': '4bf58dd8d48988d126941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4f552040e4b07e4c65aa3ab7', 'location': {'lng': -88.074641, 'city': 'Joliet', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Joliet, IL 60432', 'United States'], 'distance': 555, 'lat': 41.532329, 'postalCode': '60432', 'labeledLatLngs': [{'lng': -88.074641, 'lat': 41.532329, 'label': 'display'}]}, 'referralId': 'v-1558267860'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147d5351e3d1284c5e238'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147d6dd57970e24eb9382'}, 'response': {'venues': [{'name': 'Joliet Central High School', 'categories': [{'name': 'High School', 'shortName': 'High School', 'primary': True, 'pluralName': 'High Schools', 'id': '4bf58dd8d48988d13d941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4b7aba4ef964a5207f392fe3', 'location': {'address': '201 E Jefferson St', 'lng': -88.07414222612097, 'city': 'Joliet', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['201 E Jefferson St', 'Joliet, IL 60432', 'United States'], 'distance': 215, 'lat': 41.52633799122486, 'postalCode': '60432', 'labeledLatLngs': [{'lng': -88.07414222612097, 'lat': 41.52633799122486, 'label': 'display'}]}, 'referralId': 'v-1558267862'}, {'name': 'Jolet Central High School Little Theater', 'categories': [{'name': 'Performing Arts Venue', 'shortName': 'Performing Arts', 'primary': True, 'pluralName': 'Performing Arts Venues', 'id': '4bf58dd8d48988d1f2931735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '5088190de4b0fa42fce3bca1', 'location': {'lng': -88.073713, 'city': 'Joliet', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Joliet, IL 60432', 'United States'], 'distance': 270, 'lat': 41.525492, 'postalCode': '60432', 'labeledLatLngs': [{'lng': -88.073713, 'lat': 41.525492, 'label': 'display'}]}, 'referralId': 'v-1558267862'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147d79fb6b775bd855ce0'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147d84c1f6753b00d841e'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147d9dd57970e3956eb99'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147dadd57970e3956f10a'}, 'response': {'venues': [{'name': 'Link Office', 'categories': [{'name': 'Government Building', 'shortName': 'Government', 'primary': True, 'pluralName': 'Government Buildings', 'id': '4bf58dd8d48988d126941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4f552040e4b07e4c65aa3ab7', 'location': {'lng': -88.074641, 'city': 'Joliet', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Joliet, IL 60432', 'United States'], 'distance': 555, 'lat': 41.532329, 'postalCode': '60432', 'labeledLatLngs': [{'lng': -88.074641, 'lat': 41.532329, 'label': 'display'}]}, 'referralId': 'v-1558267866'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147dbdd57970e25ebeb45'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147dcdb04f52f654fb212'}, 'response': {'venues': [{'name': 'Grant White Elementary School', 'categories': [{'name': 'Elementary School', 'shortName': 'Elementary School', 'primary': True, 'pluralName': 'Elementary Schools', 'id': '4f4533804b9074f6e4fb0105', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '
}]}}
# {'meta': {'code': 200, 'requestId': '5ce147e1f594df57ef5439b6'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147e14434b9217ed9ca60'}, 'response': {'venues': [{'name': 'Cicero East School', 'categories': [{'name': 'Elementary School', 'shortName': 'Elementary School', 'primary': True, 'pluralName': 'Elementary Schools', 'id': '4f4533804b9074f6e4fb0105', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4f6c737de4b0e3b3bbf3487b', 'location': {'lng': -87.7469537034167, 'city': 'Cicero', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Cicero, IL 60804', 'United States'], 'distance': 465, 'lat': 41.849600210296295, 'postalCode': '60804', 'labeledLatLngs': [{'lng': -87.7469537034167, 'lat': 41.849600210296295, 'label': 'display'}]}, 'referralId': 'v-1558267873'}, {'name': 'Cicero West School', 'categories': [{'name': 'School', 'shortName': 'School', 'primary': True, 'pluralName': 'Schools', 'id': '4bf58dd8d48988d13b941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4c20d7874889a593f8fc2620', 'location': {'address': '4937 W 23rd St', 'lng': -87.74873235010065, 'city': 'Cicero', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['4937 W 23rd St', 'Cicero, IL 60804', 'United States'], 'distance': 378, 'lat': 41.849095726252514, 'postalCode': '60804', 'labeledLatLngs': [{'lng': -87.74873235010065, 'lat': 41.849095726252514, 'label': 'display'}]}, 'referralId': 'v-1558267873'}, {'name': 'Cicero School District 99', 'categories': [{'name': 'School', 'shortName': 'School', 'primary': True, 'pluralName': 'Schools', 'id': '4bf58dd8d48988d13b941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4e70deace4cd5c86942ee6a0', 'location': {'address': '5110 W 24th St', 'lng': -87.75260186709671, 'city': 'Cicero', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['5110 W 24th St', 'Cicero, IL 60804', 'United States'], 'distance': 421, 'lat': 41.847751731187195, 'postalCode': '60804', 'labeledLatLngs': [{'lng': -87.75260186709671, 'lat': 41.847751731187195, 'label': 'display'}]}, 'referralId': 'v-1558267873'}, {'name': 'Cicero Schools Transportation Center', 'categories': [{'name': 'Elementary School', 'shortName': 'Elementary School', 'primary': True, 'pluralName': 'Elementary Schools', 'id': '4f4533804b9074f6e4fb0105', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '516d4d1ce4b03347d04e0057', 'location': {'lng': -87.755413, 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Cicero, IL', 'United States'], 'distance': 347, 'lat': 41.853269, 'city': 'Cicero', 'labeledLatLngs': [{'lng': -87.755413, 'lat': 41.853269, 'label': 'display'}]}, 'referralId': 'v-1558267873'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147e29fb6b7757e92a627'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147e3f594df57eba8a82b'}, 'response': {'venues': [{'name': 'Janda Veterinary Hospital', 'categories': [{'name': 'Veterinarian', 'shortName': 'Veterinarians', 'primary': True, 'pluralName': 'Veterinarians', 'id': '4d954af4a243a5684765b473', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4f481fc6e4b0186352bd0013', 'location': {'address': '5005 W Cermak Rd', 'lng': -87.74962645421118, 'city': 'Cicero', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['5005 W Cermak Rd', 'Cicero, IL 60804', 'United States'], 'distance': 202, 'lat': 41.8509530065584, 'postalCode': '60804', 'labeledLatLngs': [{'lng': -87.74962645421118, 'lat': 41.8509530065584, 'label': 'display'}]}, 'referralId': 'v-1558267875'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147e5351e3d128729f630'}, 'response': {'venues': [{'name': 'Park', 'categories': [{'name': 'Playground', 'shortName': 'Playground', 'primary': True, 'pluralName': 'Playgrounds', 'id': '4bf58dd8d48988d1e7941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4fad6d50e4b0e981d8d026cc', 'location': {'lng': -87.75122233809994, 'city': 'Cicero', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['
}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147f0f594df57ed526daf'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147f1dd57970e39577176'}, 'response': {'venues': [{'name': 'SS Office', 'categories': [{'name': 'Building', 'shortName': 'Building', 'primary': True, 'pluralName': 'Buildings', 'id': '4bf58dd8d48988d130941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '51924ccf498e59ff6a841956', 'location': {'lng': -89.665482, 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Litchfield, IL', 'United States'], 'distance': 494, 'lat': 39.182965, 'city': 'Litchfield', 'labeledLatLngs': [{'lng': -89.665482, 'lat': 39.182965, 'label': 'display'}]}, 'referralId': 'v-1558267889'}, {'name': 'Pine Ridge Homes Office', 'categories': [{'name': 'Furniture / Home Store', 'shortName': 'Furniture / Home', 'primary': True, 'pluralName': 'Furniture / Home Stores', 'id': '4bf58dd8d48988d1f8941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4fdf3d48e4b0b4dd29ff676e', 'location': {'lng': -89.66098522619309, 'city': 'Litchfield', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Litchfield, IL 62056', 'United States'], 'distance': 592, 'lat': 39.17831627940282, 'postalCode': '62056', 'labeledLatLngs': [{'lng': -89.66098522619309, 'lat': 39.17831627940282, 'label': 'display'}]}, 'referralId': 'v-1558267889'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147f2351e3d1288bcb346'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce147f34434b9217eda2c2f'}, 'response': {'venues': [{'name': 'Big Blue Swim School', 'categories': [{'name': 'Pool', 'shortName': 'Pool', 'primary': True, 'pluralName': 'Pools', 'id': '4bf58dd8d48988d15e941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '54df90ab498e9bec970b2974', 'location': {'address': '101 McHenry Rd', 'lng': -87.95786238836058, 'city': 'Buffalo Grove', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['101 McHenry Rd', 'Buffalo Grove, IL 60089', 'United States'], 'distance': 206, 'lat': 42.155870585930415, 'postalCode': '60089', 'labeledLatLngs': [{'lng': -87.95786238836058, 'lat': 42.155870585930415, 'label': 'display'}]}, 'venuePage': {'id': '530046830'}, 'referralId': 'v-1558267891'}, {'name': 'St. Mary School', 'categories': [{'name': 'Elementary School', 'shortName': 'Elementary School', 'primary': True, 'pluralName': 'Elementary Schools', 'id': '4f4533804b9074f6e4fb0105', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '5148ee1ee4b0a02f3b6c9285', 'location': {'address': '50 N Buffalo Grove Rd', 'lng': -87.96384805237275, 'city': 'Buffalo Grove', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['50 N Buffalo Grove Rd', 'Buffalo Grove, IL 60089', 'United States'], 'distance': 334, 'lat': 42.153946221234776, 'postalCode': '60089', 'labeledLatLngs': [{'lng': -87.96384805237275, 'lat': 42.153946221234776, 'label': 'display'}]}, 'referralId': 'v-1558267891'}, {'name': "St. Mary's School Gym", 'categories': [], 'hasPerk': False, 'id': '4d1a843902a66dcb73df6065', 'location': {'address': '50 Buffalo Grove Road', 'lng': -87.963294, 'state': 'Illinois', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['50 Buffalo Grove Road', 'Illinois', 'United States'], 'distance': 318, 'lat': 42.153411, 'labeledLatLngs': [{'lng': -87.963294, 'lat': 42.153411, 'label': 'display'}]}, 'referralId': 'v-1558267891'}]}}
# {'meta': {'code': 200, 'requestId': '5ce147f46a6071493e9703b8'}, 'response': {'venues': [{'name': 'University Gynecologic Oncology - Buffalo Grove', 'categories': [{'name': "Doctor's Office", 'shortName': "Doctor's Office", 'primary': True, 'pluralName': "Doctor's Offices", 'id': '4bf58dd8d48988d177941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '5a69026012138476a931bc59', 'location': {'address': '210 McHenry Rd', 'lng': -87.961658, 'city': 'Buffalo Grove', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': 
 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Centralia, IL 62801', 'United States'], 'distance': 243, 'lat': 38.528285327044266, 'postalCode': '62801', 'labeledLatLngs': [{'lng': -89.15022862011867, 'lat': 38.528285327044266, 'label': 'display'}]}, 'referralId': 'v-1558267903'}]}}
# {'meta': {'code': 200, 'requestId': '5ce14801351e3d1288bd040f'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14802dd57970e4d0657c8'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce148021ed21914c0cac5d6'}, 'response': {'venues': [{'name': 'Middle School', 'categories': [{'name': 'School', 'shortName': 'School', 'primary': True, 'pluralName': 'Schools', 'id': '4bf58dd8d48988d13b941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4e27339cae609b2f94eec9da', 'location': {'lng': -87.9684740289893, 'state': 'Illinois', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Illinois', 'United States'], 'distance': 262, 'lat': 42.38419071743966, 'labeledLatLngs': [{'lng': -87.9684740289893, 'lat': 42.38419071743966, 'label': 'display'}]}, 'referralId': 'v-1558267907'}]}}
# {'meta': {'code': 200, 'requestId': '5ce14804351e3d1288bd10a6'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14804db04f52f5e4269a8'}, 'response': {'venues': [{'name': 'Banfield Pet Hospital', 'categories': [{'name': 'Veterinarian', 'shortName': 'Veterinarians', 'primary': True, 'pluralName': 'Veterinarians', 'id': '4d954af4a243a5684765b473', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4e345976bd414b4ca829d17b', 'location': {'address': '6405 Grand Ave', 'lng': -87.96193340424003, 'city': 'Gurnee', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['6405 Grand Ave', 'Gurnee, IL 60031', 'United States'], 'distance': 401, 'lat': 42.383060829075134, 'postalCode': '60031', 'labeledLatLngs': [{'lng': -87.96193340424003, 'lat': 42.383060829075134, 'label': 'display'}]}, 'referralId': 'v-1558267908'}]}}
# {'meta': {'code': 200, 'requestId': '5ce14805dd57970e23ffa27b'}, 'response': {'venues': []}}
# ...
# {'meta': {'code': 200, 'requestId': '5ce14b29f594df57ec92b278'}, 'response': {'venues': [{'name': 'Office Depot', 'categories': [{'name': 'Paper / Office Supplies Store', 'shortName': 'Office Supplies', 'primary': True, 'pluralName': 'Paper / Office Supplies Stores', 'id': '4bf58dd8d48988d121951735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4b33b4e7f964a5206a1d25e3', 'location': {'address': '7001 Cermak Rd', 'lng': -87.799174, 'city': 'Berwyn', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['7001 Cermak Rd', 'Berwyn, IL 60402', 'United States'], 'distance': 315, 'lat': 41.8499943, 'postalCode': '60402', 'labeledLatLngs': [{'lng': -87.799174, 'lat': 41.8499943, 'label': 'display'}]}, 'referralId': 'v-1558268713'}, {'name': 'North Riverside Post Office', 'categories': [{'name': 'Post Office', 'shortName': 'Post Office', 'primary': True, 'pluralName': 'Post Offices', 'id': '4bf58dd8d48988d172941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4d029630e350b60ca4db7742', 'location': {'lng': -87.80469356828166, 'crossStreet': 'Harlem ave', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Riverside, IL', 'United States'], 'distance': 387, 'lat': 41.84672415975907, 'city': 'Riverside', 'labeledLatLngs': [{'lng': -87.80469356828166, 'lat': 41.84672415975907, 'label': 'display'}]}, 'referralId': 'v-1558268713'}, {'name': 'Lesters Doctor Office', 'categories': [{'name': "Doctor's Office", 'shortName': "Doctor's Office", 'primary': True, 'pluralName': "Doctor's Offices", 'id': '4bf58dd8d48988d177941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4e1f2f7414959804e9e8f6f6', 'location': {'address': '7222 harlem ave', 'crossStreet': 'cermak', 'distance': 56, 'lat': 41.8504773, 'state': 'IL', 'lng': -87.8029692, 'postalCode': '60402', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['7222 harlem ave (cermak)', 'Berwyn, IL 60402', 'United States'], 'labeledLatLngs': [{'lng': -87.8029692, 'lat': 41.8504773, 'label': 'display'}], 'city': 'Berwyn'}, 'referralId': 'v-1558268713'}, {'name': 'Social security office north riverside', 'categories': [{'name': 'Government Building', 'shortName': 'Government', 'primary': True, 'pluralName': 'Government Buildings', 'id': '4bf58dd8d48988d126941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4e14c869d4c023f705425abc', 'location': {'address': '7222 W Cermak Rd', 'lng': -87.80534328123588, 'city': 'North Riverside', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['7222 W Cermak Rd', 'North Riverside, IL 60546', 'United States'], 'distance': 228, 'lat': 41.85102827800037, 'postalCode': '60546', 'labeledLatLngs': [{'lng': -87.80534328123588, 'lat': 41.85102827800037, 'label': 'display'}]}, 'referralId': 'v-1558268713'}, {'name': 'The Law Offices of Andrew A. Barone, LLC', 'categories': [{'name': 'Lawyer', 'shortName': 'Lawyer', 'primary': True, 'pluralName': 'Lawyers', 'id': '52f2ab2ebcbc57f1066b8b3f', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '59ca93916c08d16d3f9a9b7f', 'location': {'address': '7222 W Cermak Rd Ste 104', 'crossStreet': 'Cermak & Harlem', 'distance': 210, 'lat': 41.8507964, 'state': 'IL', 'lng': -87.8052601, 'postalCode': '60546', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['7222 W Cermak Rd Ste 104 (Cermak & Harlem)', 'North Riverside, IL 60546', 'United States'], 'labeledLatLngs': [{'lng': -87.8052601, 'lat': 41.8507964, 'label': 'display'}], 'city': 'North Riverside'}, 'referralId': 'v-1558268713'}, {'name': 'Office Depot - Print & Copy Services', 'cat ...
# {'meta': {'code': 200, 'requestId': '5ce14b2a9fb6b775bbc57f9c'}, 'response': {'venues': [{'name': 'Classic Cinemas North Riverside Park Mall Theater', 'categories': [{'name': 'Multiplex', 'shortName': 'Cineplex', 'primary': True, 'pluralName': 'Multiplexes', 'id': '4bf58dd8d48988d180941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4c004252ca1920a1cf20ee81', 'location': {'address': '7501 W Cermak Rd', 'crossStreet': 'at North Riverside Mall', 'distance': 633, 'lat': 41.84719446181176, 'state': 'IL', 'lng': -87.80965187054903, 'postalCode': '60546', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['7501 W Cermak Rd (at North Riverside Mall)', 'North Riverside, IL 60546', 'United States'], 'labeledLatLngs': [{'lng': -87.80965187054903, 'lat': 41.84719446181176, 'label': 'display'}], 'city': 'North Riverside'}, 'referralId': 'v-1558268714'}, {'name': 'North Riverside Park Mall', 'events': {'count': 6, 'summary': '6 movies'}, 'categories': [{'name': 'Shopping Mall', 'shortName': 'Mall', 'primary': True, 'pluralName': 'Shopping Malls', 'id': '4bf58dd8d48988d1fd941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4c0955f0a1b32d7f478097f0', 'location': {'address': '7501 W Cermak Rd', 'crossStreet': 'at Veterans Dr', 'distance': 647, 'lat': 41.8473783998698, 'state': 'IL', 'lng': -87.80997633934021, 'postalCode': '60546', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['7501 W Cermak Rd (at Veterans Dr)', 'North Riverside, IL 60546', 'United States'], 'labeledLatLngs': [{'lng': -87.80997633934021, 'lat': 41.8473783998698, 'label': 'display'}], 'city': 'North Riverside'}, 'referralId': 'v-1558268714'}, {'name': 'Riveroaks Mall', 'categories': [{'name': 'Shopping Mall', 'shortName': 'Mall', 'primary': True, 'pluralName': 'Shopping Malls', 'id': '4bf58dd8d48988d1fd941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4eb5b41b61af0dda907bc220', 'location': {'lng': -87.80363887968207, 'city': 'Berwyn', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Berwyn, IL 60402', 'United States'], 'distance': 114, 'lat': 41.849060537020414, 'postalCode': '60402', 'labeledLatLngs': [{'lng': -87.80363887968207, 'lat': 41.849060537020414, 'label': 'display'}]}, 'referralId': 'v-1558268714'}, {'name': 'The Mall', 'categories': [{'name': 'Accessories Store', 'shortName': 'Accessories', 'primary': True, 'pluralName': 'Accessories Stores', 'id': '4bf58dd8d48988d102951735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '50d77acbe4b06bd2ec93a414', 'location': {'lng': -87.80276, 'city': 'Berwyn', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Berwyn, IL 60402', 'United States'], 'distance': 113, 'lat': 41.848963, 'postalCode': '60402', 'labeledLatLngs': [{'lng': -87.80276, 'lat': 41.848963, 'label': 'display'}]}, 'referralId': 'v-1558268714'}, {'name': 'CTA / Pace Suburban Bus Stop - North Riverside Park Mall', 'categories': [{'name': 'Bus Station', 'shortName': 'Bus Station', 'primary': True, 'pluralName': 'Bus Stations', 'id': '4bf58dd8d48988d1fe931735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '51146006f31c8ea9d925fb31', 'location': {'address': '7501 W Cermak Rd', 'crossStreet': 'Sears Wing', 'distance': 627, 'lat': 41.848457334225024, 'state': 'IL', 'lng': -87.81026601791382, 'postalCode': '60546', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['7501 W Cermak Rd (Sears Wing)', 'North Riverside, IL 60546', 'United States'], 'labeledLatLngs': [{'lng': -87.81026601791382, 'lat': 41.848457334225024, 'label': 'display'}], 'city': 'North Riverside'}, 'refe ...
# {'meta': {'code': 200, 'requestId': '5ce14b2b351e3d12873bb717'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b2c9fb6b775959eabcc'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b2c351e3d1284d809a3'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b2ff594df57ec92d427'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b2fdd57970e4d179d54'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b304434b921694f1f5f'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b31dd57970e4d17a4fe'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b314c1f6753b3ca5f4c'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b32f594df57ed641b26'}, 'response': {'venues': [{'name': 'Belvidere Family Pet Hospital', 'categories': [{'name': 'Veterinarian', 'shortName': 'Veterinarians', 'primary': True, 'pluralName': 'Veterinarians', 'id': '4d954af4a243a5684765b473', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '50e60cd7e4b083b3f8133ce2', 'location': {'address': '2090 Pearl St', 'crossStreet': 'at US 20', 'distance': 237, 'lat': 42.23793029785156, 'state': 'IL', 'lng': -88.84136962890625, 'postalCode': '61008', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['2090 Pearl St (at US 20)', 'Belvidere, IL 61008', 'United States'], 'labeledLatLngs': [{'lng': -88.84136962890625, 'lat': 42.23793029785156, 'label': 'display'}], 'city': 'Belvidere'}, 'referralId': 'v-1558268722'}, {'name': 'Swedish American Medical Center', 'categories': [{'name': 'Hospital', 'shortName': 'Hospital', 'primary': True, 'pluralName': 'Hospitals', 'id': '4bf58dd8d48988d196941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4e0340e7b0fb88a1209cb806', 'location': {'address': '1625 S State St', 'crossStreet': '9th', 'distance': 364, 'lat': 42.24317753296076, 'state': 'IL', 'lng': -88.83989087707042, 'postalCode': '61008', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['1625 S State St (9th)', 'Belvidere, IL 61008', 'United States'], 'labeledLatLngs': [{'lng': -88.83989087707042, 'lat': 42.24317753296076, 'label': 'display'}], 'city': 'Belvidere'}, 'referralId': 'v-1558268722'}]}}
# {'meta': {'code': 200, 'requestId': '5ce14b336a6071493b7d62a1'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b346a60714940754532'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b34dd57970e24fddc47'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b354434b921402947e3'}, 'response': {'venues': [{'name': 'Emge Junior High School', 'categories': [{'name': 'Middle School', 'shortName': 'Middle School', 'primary': True, 'pluralName': 'Middle Schools', 'id': '4f4533814b9074f6e4fb0106', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}}], 'hasPerk': False, 'id': '4cf82b65951537042c965a89', 'location': {'address': 'Westchester Dr.', 'lng': -90.05706779750636, 'city': 'Belleville', 'state': 'IL', 'cc': 'US', 'country': 'United States', 'formattedAddress': ['Westchester Dr.', 'Belleville, IL 62223', 'United States'], 'distance': 549, 'lat': 38.54827929210212, 'postalCode': '62223', 'labeledLatLngs': [{'lng': -90.05706779750636, 'lat': 38.54827929210212, 'label': 'display'}]}, 'referralId': 'v-1558268725'}]}}
# {'meta': {'code': 200, 'requestId': '5ce14b36dd57970e20249ca8'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b376a6071493ea8b9a7'}, 'response': {'venues': []}}
# {'meta': {'code': 200, 'requestId': '5ce14b389fb6b7757fff2ed3'}, 'response': {'venues': []}}
# {'meta': {'errorType': 'quota_exceeded', 'code': 429, 'requestId': '5ce14b39db04f52f6561f808', 'errorDetail': 'Quota exceeded'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-a8177b8c493a> in <module>()
#      56
#      57 df_il.reset_index()
# ---> 58 df_il = df_il.apply(get_neighbours,axis=1)
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-30-a8177b8c493a> in get_neighbours(each_)
#      37         each_['park'] = 0
#      38
# ---> 39     each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'office')
#      40     if not (type(each_venue) is str):
#      41         each_['offices'] = len(each_venue.index)
#
# <ipython-input-20-49d723ba97e4> in get_venue_search(self, latitude, longitude, search_query, radius)
#      32         results = requests.get(url).json()
#      33         print(results)
# ---> 34         venues = results['response']['venues']
#      35         if not len(venues):
#      36             dataframe_filtered = 'No Venues Available'
#
# KeyError: ('venues', 'occurred at index 4258')

# %%
whut = fsq.get_venue_search(41.527670,-88.072261,'school')
whut

# %%
# 'burgerbasket': Int64Index([2430], dtype='int64'),
#  'burgerfi': Int64Index([7949], dtype='int64'),
#  'burgerhouse': Int64Index([8288], dtype='int64'),
#  'burgerking': Int64Index([ 3356, 19830,  3358, 12296, 12297,  3359,  3357,  3355, 18579,
#                546,
#              ...
#              11838, 14261, 11836,  7923, 10708, 15594, 19498, 19496, 10685,
#              11274],
#             dtype='int64', length=1987),
#  'burgerkingpopeyes': Int64Index([5950], dtype='int64'),
#  'burgerkingsalou': Int64Index([17684], dtype='int64'),
#  'burgerkingæ': Int64Index([9107], dtype='int64'),
#  'burgerslanding': Int64Index([14335], dtype='int64'),
#  'burgertime': Int64Index([12093], dtype='int64'),
#  'burgerville': Int64Index([19340], dtype='int64'),
#  'burgervilleusa'
fuzz.partial_ratio('aw', 'awallamericanfood')

# %%
fg=pd.DataFrame([[1,2],[3,4]],columns=['a','b'])

# %%
df_split = pd.DataFrame([],columns=df.columns)
df_split

# %%
pd.concat([fg, pd.DataFrame([[5,6]],columns=['a','b'])],ignore_index=1)
