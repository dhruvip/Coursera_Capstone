# %% [markdown]
# **Loading libraries**

# %%
#https://www.worldatlas.com/articles/the-most-visited-states-in-the-us.html
#https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_area
#https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population
# https://stats.stackexchange.com/questions/174383/how-to-predict-outcome-with-only-positive-cases-as-trai/n/ing
# https://www.google.com/search?q=what+happens+when+a+classification+model+is+trained+only+on+positive+cases+site:stats.stackexchange.com&client=ubuntu&channel=fs&sa=X&ved=2ahUKEwiCn82O2qXiAhUkSo8KHXRBAfcQrQIoBDAKegQIAxAM&biw=1311&bih=673
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup 
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
# from FourSquareAPI import FourSquareAPI
import folium 
from IPython.display import Image 
from IPython.core.display import HTML 
import matplotlib.cm as cm
import matplotlib.colors as colors

# %matplotlib inline 
mpl.style.use('ggplot')

class FourSquareAPI():
    def __init__(self, client_id, client_secret, version='20180604', limit=30):
        self.client_id = client_id
        self.client_secret = client_secret
        self.version = version
        self.limit = limit
        
    def get_venue_search(self, latitude, longitude, search_query, radius=500):
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.\
format(self.client_id, self.client_secret, latitude, longitude, self.version, search_query, radius, self.limit)
        results = requests.get(url).json()
        print(results)
        venues = results['response']['venues']
        if not len(venues):
            dataframe_filtered = 'No Venues Available'
        else:
            df = json_normalize(venues)
            # keep only columns that include venue name, and anything that is associated with location
            filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
            dataframe_filtered = df.loc[:, filtered_columns]

            # function that extracts the category of the venue
            def get_category_type(row):
                try:
                    categories_list = row['categories']
                except:
                    categories_list = row['venue.categories']

                if len(categories_list) == 0:
                    return None
                else:
                    return categories_list[0]['name']

            # filter the category for each row
            dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
            dataframe_filtered['search_q'] = search_query
            # clean column names by keeping only last term
            dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

        return dataframe_filtered
    
    def get_trending_places(self, latitude, longitude):
        url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.\
        format(self.client_id, self.client_secret, latitude, longitude, self.version)
        results = requests.get(url).json()
        if len(results['response']['venues']) == 0:
            trending_venues_df = 'No trending venues are available at the moment!'
        else:
            trending_venues = results['response']['venues']
            trending_venues_df = json_normalize(trending_venues)
            columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
            trending_venues_df = trending_venues_df.loc[:, columns_filtered]
            trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
        return trending_venues_df
#dpandya@accionlabs.com
# fsq = FourSquareAPI('C3O4QWMMAMXNTN1AA3THAESPK1TR4LR4431135B34ZFBK0XW','2G2RX4OUQJ4QBDQDRD2BB4521RIG0TKQ3RLPSIHU0GYZWQIL')
#dhruvi.pandya.7294@gmail.com
# fsq = FourSquareAPI('QRTP4LWZZWCQEVRBNPS0P4D1W33WZZ4YMSYDZXJ0NISIL3JI','NVKCW0IHZFGE340QPJGVG2AX1C1DZ2V3QKNVGCZYTWI4TNIK')
#dhruvi.pandya@accionlabs.com
# fsq = FourSquareAPI('UUW2AVFXB4IBLQNORRJ5XSDWQY2Q3WRF4FJY435N3N3KCFJT','BNJIBTZDPD3VIRSR2RS5CVYPFHTNXX3TBT3YFL3J532PIXR1')
#vishal.bhat@accionlabs.com
# fsq = FourSquareAPI('UUQV3BE5IMRX4AKQXPQ2F24JPLTDW0PA032AZFQ3JLLZFQBD','4H02CJ03DHZRUOTTFQPQJDTVWEPUHD5FUTOR1BYL1MDYEQBY')
#dpandya@fpg-ingauge.com
# fsq = FourSquareAPI('ZVPUWGOQCRWXGGQRV3I1AVCUHFOTPM3W1SEGFGB4FHDRAKIQ','0VL2T5M4WSOEPJESEBYHUVEVW0IM3IWSRNXO2E10RB0DLX0P')
#vbhat1989@gmail.com
# fsq = FourSquareAPI('NASZAA5SY2CAKAKB4U1Q3ZFIVO5DC0ZVAREU5354ZQNDYQMW','ZDSBIKMQV44AT40R0FHMQ311U5EW5NSVLITPLQQIVRETBVTK')
#dnp7294@yahoo.com
# fsq = FourSquareAPI('MQDE0SDDPPBDCIPVSG5CITKLGECLDGWXZGZ2QXWCR1CZ0TAX','YQPPFYOG3LVMCAJDBFT5BPBVXVRFSENZ4PRBPTYSGNB0PYYT')
# dnp7294@fpg-ingauge.com
# fsq = FourSquareAPI('VVCGZLZWWA3TURUMB0QM0TN4PBM3BLL4M2CWJ15VXNDU41OS','UHLVEHOC2XWKXN1Z12MTZTI2BGCR3ZIVGOXB5WPY1Z5HZYUU')
# dnp@accionlabs.com
# fsq = FourSquareAPI('LDMQUZQMVBX2BRJZH15HPOPQTRQJVBXIMLGTKWN0ILSEKJTL','GA4EVZLIHBTXPILOTKGND2MWWQPT4M3QZOBE3LDINESW3R2W')
# stuti.dwivedi@accionlabs.com
# fsq = FourSquareAPI('YJCRRMCABTMD2AT5GLPK5TE1MBYLRM4ZVYWHLPEORCFOX5TA','WYUSBQI5KDYJZA4IHQSIIQFK30JOTXQ3IU1WVKCUCMYINJXI')
# stuti.dwivedi@fpg-ingauge.com
# fsq = FourSquareAPI('OUDSRVDR0G1OCDGMUIYVQQGIR0L233B0XJ1ZUWMGB3YY3DO5','KPP3M3X5VQU3IKIL4TXCECQ5HTW1T2VWPCHQJ2TA0XFJVNQR')
# sdwivedi@accionlabs.com
# fsq = FourSquareAPI('R3ZLLHEH0O5JUTW1WCHYKCIJCJOXCCMLQ1SWDRKAWZ5LHAKV','DDPOUXCMK0130CDGQ1QYVFCBCDGEP33RTUO2GRBC4TSWCXWT')
# vbhat@accionlabs.com
fsq = FourSquareAPI('ZCGZ0ZCXNCGA4AZXU45POZPDHB0NBMK5BN1XH3WLI40QBT4W','W0FOC0IO2BZW2WCSTLCCVZUBPMQ5WCGLKJTSTHINP1TERHSP')
# vbhat@fpg-ingauge.com
# fsq = FourSquareAPI('EWF1DR4ZLFKVFRVO05Q2PBJKCIYEHTG5SD2ZW4Z1Q4TT5ZYB','2TRKF3PCFM0METPCQT1WWVCVQIGBFXDBLCXEJWMXSZDXDYUO')

# %% [markdown]
# **Reading data files**

# %%
df1 = pd.read_csv('fast-food-restaurants/Datafiniti_Fast_Food_Restaurants.csv')
df2 = pd.read_csv('fast-food-restaurants/FastFoodRestaurants.csv')

# %% [markdown]
# **Cleaning data and saving it to a csv file**

# %%
df1 = df1[['address','categories','city','country','latitude','longitude','name','postalCode','province']]
df2 = df2[['address','city','country','latitude','longitude','name','postalCode','province']]
df = pd.concat([df1,df2], ignore_index=True)
df.sort_values(by='name',inplace=True)
df_split =  list()
for index, each_ in df.iterrows():
    name = each_['name'].split('/')
    if len(name) > 1:
        each_['name'] = name[0]
        new_ = each_.copy()
        new_['name'] = name[1]
        if not len(df_split):
            df_split = each_.values
        else: 
            df_split = np.vstack((df_split, each_.values))
        df_split = np.vstack((df_split, new_.values))        
    else:      
        if not len(df_split):
            df_split = each_.values
        else: 
            df_split = np.vstack((df_split, each_.values))

df_split = pd.DataFrame(df_split, columns=df.columns)
df_split['cleaned_name'] = df_split['name'].copy()
def strip_sp_charac(x):
    x['cleaned_name'] = ''.join(e for e in x['cleaned_name'] if e.isalnum())
    x['cleaned_name'] = x['cleaned_name'].lower()
    return x
df_split = df_split.apply(strip_sp_charac, axis=1)
df_split = df_split.drop_duplicates(['latitude','longitude','name'],keep='last')
df_split.to_csv('fast-food-restaurants/cleaned-data-all.csv')

# %% [markdown]
# **Reading cleaned data from csv file**

# %%
df_split= pd.read_csv('fast-food-restaurants/cleaned-data-all.csv')

# %%
df_grp_by = df_split.groupby('cleaned_name', as_index=False)
(df_grp_by.size()).sort_values(ascending=True, inplace=True)
df_agg = df_grp_by.count().sort_values('address')
df_top100_list = df_agg[df_agg['address']>100]['cleaned_name'].values

# %% [markdown]
# **DataFrame of restaurant with more than 100 outlets all over US**

# %%
df_top100 = df_split.loc[df_split['cleaned_name'].isin(df_top100_list)]
df_top100.drop('Unnamed: 0',axis=1, inplace=True)
df_top100.head()
# Out:
# /home/dhruvi/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                 address categories          city country   latitude  \
# 69      1027 Ne Rice Rd        NaN   Lees Summit      US  38.931200
# 70       717 S Bluff St        NaN  Saint George      US  37.096080
# 71  3200 W Mercury Blvd  Fast Food       Hampton      US  37.033187
# 72       2489 S Main St        NaN     Bountiful      US  40.862630
# 73        109 Market Dr  Fast Food       Emporia      US  36.703902
#
#      longitude    name postalCode province cleaned_name
# 69  -94.358900  Arby's      64086       MO        arbys
# 70 -113.586490  Arby's      84770       UT        arbys
# 71  -76.417821  Arby's      23666       VA        arbys
# 72 -111.895090  Arby's      84010       UT        arbys
# 73  -77.541463  Arby's      23847       VA        arbys

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 9
df_top100.groupby('cleaned_name')['province'].count().plot(
    kind='bar',
    label='# Outlets',
    y='province',
    x='count'
)
plt.title('Number of Outlets per franchise in USA')
plt.ylabel('# Outlets')
plt.xlabel('Franchise')

# %% [markdown]
# **Province in Top 75% of the Fast Food Restaurant distribution**

# %%
df_plot = df_top100.groupby('province')['name'].count()
province_75q = df_top100.groupby('province')['name'].count().quantile(0.75)
x = df_plot.index
top25_list = df_plot[df_plot > province_75q].index.values

# %%
fig,ax = plt.subplots()
df_plot.plot(kind='bar',ax=ax, label='Province')
ax.plot(x,[province_75q]*len(x), label='75% percentile', linestyle='--')
legend = ax.legend(loc='upper right')
plt.title('Number of Fast Food restaurants per Province')
plt.xlabel('Province')
plt.ylabel('# Count')
plt.show()
print('Provinces which lie in the top 25% of the restaurant distribution are: ', \
      top25_list)

# %%
df_top25 = df_top100.loc[df_top100['province'].isin(top25_list)]
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 12
fig_size[1] = 9
colors = ['red','blue','lightgreen','darkgreen','purple','yellow','orange','violet','lightblue',\
          'black','grey','brown','pink']

# %%
df_top25.groupby('province').count().plot(kind='pie',y='address',label='Province', colors=colors)
plt.title('Distribution within the top 25% province')

# %% [markdown]
# **Creating a meta data dataframe for provinces**

# %%
#most_visited_list = ['CA','FL','NV','TX','NY','VA','SC','AZ','GA','HI']
df_province = pd.read_csv('province_meta_data.csv')
df_province['rest_per_km2'] = df_province['restaurants_in_province']/df_province['area_km2']
df_province['rest_per_1000people'] = df_province['restaurants_in_province']/df_province['population'] * 1000
df_province
# Out:
#     Unnamed: 0  area_km2  population province  is_tourist  \
# 0            0    403466    39557045       CA           1
# 1            1    138887    21299325       FL           1
# 2            2    148959    10519475       GA           1
# 3            3    143793    12741080       IL           0
# 4            4     92789     6691878       IN           0
# 5            5    146435     9995915       MI           0
# 6            6    125920    10383620       NC           0
# 7            7    122057    19542209       NY           1
# 8            8    105829    11689442       OH           0
# 9            9    115883    12807060       PA           0
# 10          10    106798     6770010       TN           0
# 11          11    676587    28701845       TX           1
# 12          12    102279     8517685       VA           1
#
#     restaurants_in_province  rest_per_km2  rest_per_1000people
# 0                      1337      0.003314             0.033799
# 1                       874      0.006293             0.041034
# 2                       636      0.004270             0.060459
# 3                       571      0.003971             0.044816
# 4                       502      0.005410             0.075016
# 5                       507      0.003462             0.050721
# 6                       561      0.004455             0.054027
# 7                       488      0.003998             0.024972
# 8                       821      0.007758             0.070234
# 9                       521      0.004496             0.040681
# 10                      452      0.004232             0.066765
# 11                     1104      0.001632             0.038464
# 12                      501      0.004898             0.058819

# %%
df_top25 = pd.merge(df_top25, df_province, on='province',how='left')
df_top25.drop(['Unnamed: 0','area_km2','population', 'restaurants_in_province'], axis=1, inplace=True)
df_top25.head()
# Out:
#                 address             categories             city country  \
# 0   3200 W Mercury Blvd              Fast Food          Hampton      US
# 1         109 Market Dr              Fast Food          Emporia      US
# 2  1700 Timberwood Blvd  Fast Food Restaurants  Charlottesville      US
# 3         193 Grant Ave   Fast Food Restaurant           Auburn      US
# 4        2255 Us Hwy 27                    NaN         Clermont      US
#
#     latitude  longitude    name postalCode province cleaned_name  is_tourist  \
# 0  37.033187 -76.417821  Arby's      23666       VA        arbys           1
# 1  36.703902 -77.541463  Arby's      23847       VA        arbys           1
# 2  38.129807 -78.437118  Arby's      22911       VA        arbys           1
# 3  42.948394 -76.548617  Arby's      13021       NY        arbys           1
# 4  28.539043 -81.738181  Arby's      34711       FL        arbys           1
#
#    rest_per_km2  rest_per_1000people
# 0      0.004898             0.058819
# 1      0.004898             0.058819
# 2      0.004898             0.058819
# 3      0.003998             0.024972
# 4      0.006293             0.041034

# %%
df_top25.rename({'is_tourist':'is_tourist_province',
                'rest_per_km2': 'rest_per_km2_province',
                'rest_per_1000people':'rest_per_1000people_province'}, axis=1,inplace=True)
df_top25.head()
# Out:
#                 address             categories             city country  \
# 0   3200 W Mercury Blvd              Fast Food          Hampton      US
# 1         109 Market Dr              Fast Food          Emporia      US
# 2  1700 Timberwood Blvd  Fast Food Restaurants  Charlottesville      US
# 3         193 Grant Ave   Fast Food Restaurant           Auburn      US
# 4        2255 Us Hwy 27                    NaN         Clermont      US
#
#     latitude  longitude    name postalCode province cleaned_name  \
# 0  37.033187 -76.417821  Arby's      23666       VA        arbys
# 1  36.703902 -77.541463  Arby's      23847       VA        arbys
# 2  38.129807 -78.437118  Arby's      22911       VA        arbys
# 3  42.948394 -76.548617  Arby's      13021       NY        arbys
# 4  28.539043 -81.738181  Arby's      34711       FL        arbys
#
#    is_tourist_province  rest_per_km2_province  rest_per_1000people_province
# 0                    1               0.004898                      0.058819
# 1                    1               0.004898                      0.058819
# 2                    1               0.004898                      0.058819
# 3                    1               0.003998                      0.024972
# 4                    1               0.006293                      0.041034

# %%
df_top25.shape

# %%
df_top25.sort_values(ascending=True, by='province',inplace=True)
df_top25_grpby = df_top25.groupby('province')
# df_top25.set_index(['province', 'cleaned_name'], inplace=True)

# %% [markdown]
# **Exploring for ILLINOIS**

# %%
df_il = df_top25_grpby.get_group('IL')
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans , DBSCAN

X = df_top25[['latitude','longitude']].values
Clus_dataSet = StandardScaler().fit_transform(X)
clusterNum = 4
# k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
# k_means.fit(X)
# labels = k_means.labels_

epsilon = 0.3
minimumSamples = 7
db = DBSCAN(eps=epsilon, min_samples=minimumSamples).fit(X)
labels = db.labels_

df_top25['labels'] = labels

# %%
df_top25.head()

# %%
from IPython.display import Image 
from IPython.core.display import HTML 
import random

number_of_colors = len(labels)

colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]

usmap = folium.Map(location=[41.5277,-88.0723], zoom_start=11) 


# for name, group in df_top25_grpby:
for index, each_ in df_top25.iterrows():
    popup=folium.Popup(each_['name'], parse_html=True)
    if each_['labels'] < 0 :
        continue
    folium.features.CircleMarker(
        [each_['latitude'], each_['longitude']],
        radius=2,
        color=colors[each_['labels']],
        popup= popup,
        fill = True,
        fill_color = colors[each_['labels']],
        fill_opacity = 0.6
    ).add_to(usmap)
usmap

# %%
df_il.shape

# %%
usmap.save('top25.html')

# %% [markdown]
# **Further calculation**

# %%
df_top25.at[839,:]

# %%
whuut = df_top25.iloc[1]
whuut = pd.DataFrame(whuut)
whuut.T.to_csv('test.csv', index=False, sep=',',header=False, index_label=None, mode='a')
print(pd.__version__)

# %%
df_top25[4245:]
# Out:
#                                       address  \
# 4245                          4210 Summer Ave
# 4246                       950 State Route 36
# 4247                        2900 Wendell Blvd
# 4248                         718 Canton Rd NW
# 4249           108 N Interstate 45 Service Rd
# 4250                           10141 N 2nd St
# 4251                             2870 3rd Ave
# 4252                            2900 W 5th St
# 4253                    8834 W State Road 114
# 4254                           1422 S Main St
# 4255                            2659 Front St
# 4256                           7181 Cermak Rd
# 4257                        240 W Chrysler Dr
# 4258                  7301 Westfield Plaza Dr
# 4259                           1023 N Lake St
# 4260                       188 Fox Valley Ctr
# 4261                           1402 SE 3rd St
# 4262                       500 E Algonquin Rd
# 4263                         125 S Randall Rd
# 4264                    2636 Wesley Chapel Rd
# 4265                      2050 State Rte 60 E
# 4266                      620 N Countyline St
# 4267                    1714 W State Route 18
# 4268                            1067 N Bridge
# 4269                              300 28th St
# 4270                               7800 Sr 45
# 4271                          1400 Lowes Blvd
# 4272                      960 Schuylkill Mall
# 4273                9460 W Sam Houston Pkwy S
# 4274                              2101 7th St
# ...                                       ...
# 8846                     11075 Gateway Blvd W
# 8847           215 N Interstate 45 Service Rd
# 8848                             1301 Hwy 100
# 8849                            6300 Gulf Fwy
# 8850                      13270 Northwest Fwy
# 8851                        1701 S Beckley Rd
# 8852                     15329 Wallisville Rd
# 8853                         2509 Trimmier Rd
# 8854                         7165 Philips Hwy
# 8855                         501 E Highway 67
# 8856                     5401 FM 1626 Ste 500
# 8857                        2120 E Paisano Dr
# 8858                            510 S 14th St
# 8859                      140 Interstate 45 S
# 8860                          1243 Austin Hwy
# 8861                              3510 N Main
# 8862                                505 US-83
# 8863                          8055 North Loop
# 8864                        2214 N Collins St
# 8865                       2236 Jacksboro Hwy
# 8866                          5060 Highway 78
# 8867                              729 Hwy 361
# 8868                           100 W Loop 340
# 8869                          1243 Austin Hwy
# 8870                          7430 Louetta Rd
# 8871     4021 Interstate Highway 69 Access Rd
# 8872                           955 N Beach St
# 8873                       123 Creekside Xing
# 8874                   670 Old San Antonio Rd
# address                                   NaN
#
#                                                 categories            city  \
# 4245                                  Fast Food Restaurant         Memphis
# 4246                                                   NaN         Hornell
# 4247                                 Fast Food Restaurants         Wendell
# 4248                                                   NaN      Carrollton
# 4249                                                   NaN        Hutchins
# 4250                                                   NaN  Machesney Park
# 4251                                                   NaN           Bronx
# 4252                                             Fast Food       Lumberton
# 4253                                                   NaN      Rensselaer
# 4254                                                   NaN         Red Bud
# 4255                                                   NaN       Richlands
# 4256                                 Fast food restaurants          Berwyn
# 4257                                  Fast Food Restaurant       Belvidere
# 4258                                             Fast Food      Belleville
# 4259                                             Fast Food          Aurora
# 4260                                             Fast Food          Aurora
# 4261                                 Fast Food Restaurants           Aledo
# 4262                                             Fast Food       Algonquin
# 4263                                  Fast Food Restaurant       Algonquin
# 4264                                                   NaN         Decatur
# 4265                                                   NaN         Valrico
# 4266                                                   NaN        Fostoria
# 4267                                                   NaN          Tiffin
# 4268                                                   NaN     Chillicothe
# 4269                                                   NaN        Bellaire
# 4270                                                   NaN          Lisbon
# 4271                                                   NaN         Killeen
# 4272                                                   NaN      Frackville
# 4273                                                   NaN         Houston
# 4274                                                   NaN        Bay City
# ...                                                    ...             ...
# 8846                                                   NaN         El Paso
# 8847                                                   NaN        Hutchins
# 8848                                                   NaN     Port Isabel
# 8849                                                   NaN       La Marque
# 8850                                                   NaN         Houston
# 8851                                 Fast Food Restaurants         Red Oak
# 8852                                                   NaN         Houston
# 8853                                                   NaN         Killeen
# 8854                                                   NaN    Jacksonville
# 8855                                 Fast food restaurants     Duncanville
# 8856                                                   NaN            Kyle
# 8857                                                   NaN         El Paso
# 8858                                                   NaN      Kingsville
# 8859                                                   NaN      Huntsville
# 8860     Burger Joint and Fast Food Restaurant Terrell ...     San Antonio
# 8861                                                   NaN          Taylor
# 8862                                                   NaN            Roma
# 8863                                                   NaN         El Paso
# 8864                                                   NaN       Arlington
# 8865                                                   NaN      Fort Worth
# 8866                                                   NaN          Sachse
# 8867                                                   NaN    Port Aransas
# 8868                                                   NaN         Woodway
# 8869                                                   NaN     San Antonio
# 8870                                                   NaN          Spring
# 8871                                                   NaN  Corpus Christi
# 8872                                                   NaN      Fort Worth
# 8873                                                   NaN   New Braunfels
# 8874                                                   NaN            Buda
# address                                                NaN             NaN
#
#         country   latitude   longitude         name postalCode province  \
# 4245         US  35.149388  -89.920422   McDonald's      38122       TN
# 4246         US  42.345460  -77.666800   McDonald's      14843       NY
# 4247         US  35.792697  -78.379030   McDonald's      27591       NC
# 4248         US  40.582420  -81.091610   McDonald's      44615       OH
# 4249         US  32.649190  -96.707080   McDonald's      75141       TX
# 4250         US  42.366211  -89.032520   McDonald's      61115       IL
# 4251         US  40.816434  -73.916967   McDonald's      10455       NY
# 4252         US  34.622920  -79.047438   McDonald's      28358       NC
# 4253         US  40.941370  -87.216330   McDonald's      47978       IN
# 4254         US  38.198850  -89.993870   McDonald's      62278       IL
# 4255         US  37.094160  -81.812290   McDonald's      24641       VA
# 4256         US  41.849966  -87.802979   McDonald's      60402       IL
# 4257         US  42.240066  -88.841255   McDonald's      61008       IL
# 4258         US  38.545182  -90.052155   McDonald's      62223       IL
# 4259         US  41.778876  -88.315713   McDonald's      60506       IL
# 4260         US  41.759701  -88.208402   McDonald's      60504       IL
# 4261         US  41.199464  -90.733615   McDonald's      61231       IL
# 4262         US  42.163979  -88.285165   McDonald's      60102       IL
# 4263         US  42.173932  -88.335286   McDonald's      60102       IL
# 4264         US  33.710670  -84.217060   McDonald's      30034       GA
# 4265         US  27.938400  -82.253200   McDonald's      33594       FL
# 4266         US  41.164630  -83.420520   McDonald's      44830       OH
# 4267         US  41.111300  -83.203600   McDonald's      44883       OH
# 4268         US  39.357300  -82.975700   McDonald's      45601       OH
# 4269         US  40.011480  -80.745750   McDonald's      43906       OH
# 4270         US  40.787800  -80.775100   McDonald's      44432       OH
# 4271         US  31.089960  -97.729170   McDonald's      76542       TX
# 4272         US  40.771170  -76.237310   McDonald's      17931       PA
# 4273         US  29.676140  -95.560730   McDonald's      77099       TX
# 4274         US  28.983640  -95.964940   McDonald's      77414       TX
# ...         ...        ...         ...          ...        ...      ...
# 8846         US  31.745050 -106.331820  Whataburger      79935       TX
# 8847         US  32.650060  -96.709110  Whataburger      75141       TX
# 8848         US  26.071100  -97.221800  Whataburger      78578       TX
# 8849         US  29.367600  -94.974160  Whataburger      77568       TX
# 8850         US  29.848671  -95.503555  Whataburger      77040       TX
# 8851         US  32.560257  -96.823426  Whataburger      75154       TX
# 8852         US  29.808039  -95.168080  Whataburger      77049       TX
# 8853         US  31.090560  -97.734330  Whataburger      76542       TX
# 8854         US  30.242620  -81.598010  Whataburger      32256       FL
# 8855         US  32.633460  -96.900821  Whataburger      75137       TX
# 8856         US  30.015870  -97.862320  Whataburger      78640       TX
# 8857         US  31.765962 -106.461571  Whataburger      79905       TX
# 8858         US  27.512460  -97.855510  Whataburger      78363       TX
# 8859         US  30.715700  -95.566940  Whataburger      77340       TX
# 8860         US  29.488978  -98.444786  Whataburger      78209       TX
# 8861         US  30.598685  -97.415188  Whataburger      76574       TX
# 8862         US  26.402600  -99.006400  Whataburger      78584       TX
# 8863         US  31.729040 -106.348010  Whataburger      79915       TX
# 8864         US  32.770013  -97.097865  Whataburger      76011       TX
# 8865         US  32.784690  -97.380500  Whataburger      76114       TX
# 8866         US  32.969050  -96.605660  Whataburger      75048       TX
# 8867         US  27.827160  -97.067260  Whataburger      78373       TX
# 8868         US  31.512110  -97.187240  Whataburger      76712       TX
# 8869         US  29.488710  -98.444700  Whataburger      78209       TX
# 8870         US  30.019000  -95.527460  Whataburger      77379       TX
# 8871         US  27.856990  -97.630670  Whataburger      78410       TX
# 8872         US  32.776688  -97.289947  Whataburger      76111       TX
# 8873         US  29.727900  -98.076120  Whataburger      78130       TX
# 8874         US  30.086880  -97.822510  Whataburger      78610       TX
# address     NaN        NaN         NaN          NaN        NaN      NaN
#
#         cleaned_name  is_tourist_province  rest_per_km2_province  \
# 4245       mcdonalds                  0.0               0.004232
# 4246       mcdonalds                  1.0               0.003998
# 4247       mcdonalds                  0.0               0.004455
# 4248       mcdonalds                  0.0               0.007758
# 4249       mcdonalds                  1.0               0.001632
# 4250       mcdonalds                  0.0               0.003971
# 4251       mcdonalds                  1.0               0.003998
# 4252       mcdonalds                  0.0               0.004455
# 4253       mcdonalds                  0.0               0.005410
# 4254       mcdonalds                  0.0               0.003971
# 4255       mcdonalds                  1.0               0.004898
# 4256       mcdonalds                  0.0               0.003971
# 4257       mcdonalds                  0.0               0.003971
# 4258       mcdonalds                  0.0               0.003971
# 4259       mcdonalds                  0.0               0.003971
# 4260       mcdonalds                  0.0               0.003971
# 4261       mcdonalds                  0.0               0.003971
# 4262       mcdonalds                  0.0               0.003971
# 4263       mcdonalds                  0.0               0.003971
# 4264       mcdonalds                  1.0               0.004270
# 4265       mcdonalds                  1.0               0.006293
# 4266       mcdonalds                  0.0               0.007758
# 4267       mcdonalds                  0.0               0.007758
# 4268       mcdonalds                  0.0               0.007758
# 4269       mcdonalds                  0.0               0.007758
# 4270       mcdonalds                  0.0               0.007758
# 4271       mcdonalds                  1.0               0.001632
# 4272       mcdonalds                  0.0               0.004496
# 4273       mcdonalds                  1.0               0.001632
# 4274       mcdonalds                  1.0               0.001632
# ...              ...                  ...                    ...
# 8846     whataburger                  1.0               0.001632
# 8847     whataburger                  1.0               0.001632
# 8848     whataburger                  1.0               0.001632
# 8849     whataburger                  1.0               0.001632
# 8850     whataburger                  1.0               0.001632
# 8851     whataburger                  1.0               0.001632
# 8852     whataburger                  1.0               0.001632
# 8853     whataburger                  1.0               0.001632
# 8854     whataburger                  1.0               0.006293
# 8855     whataburger                  1.0               0.001632
# 8856     whataburger                  1.0               0.001632
# 8857     whataburger                  1.0               0.001632
# 8858     whataburger                  1.0               0.001632
# 8859     whataburger                  1.0               0.001632
# 8860     whataburger                  1.0               0.001632
# 8861     whataburger                  1.0               0.001632
# 8862     whataburger                  1.0               0.001632
# 8863     whataburger                  1.0               0.001632
# 8864     whataburger                  1.0               0.001632
# 8865     whataburger                  1.0               0.001632
# 8866     whataburger                  1.0               0.001632
# 8867     whataburger                  1.0               0.001632
# 8868     whataburger                  1.0               0.001632
# 8869     whataburger                  1.0               0.001632
# 8870     whataburger                  1.0               0.001632
# 8871     whataburger                  1.0               0.001632
# 8872     whataburger                  1.0               0.001632
# 8873     whataburger                  1.0               0.001632
# 8874     whataburger                  1.0               0.001632
# address          NaN                  NaN                    NaN
#
#          rest_per_1000people_province  api_call_made
# 4245                         0.066765          False
# 4246                         0.024972          False
# 4247                         0.054027          False
# 4248                         0.070234          False
# 4249                         0.038464          False
# 4250                         0.044816          False
# 4251                         0.024972          False
# 4252                         0.054027          False
# 4253                         0.075016          False
# 4254                         0.044816          False
# 4255                         0.058819          False
# 4256                         0.044816          False
# 4257                         0.044816          False
# 4258                         0.044816          False
# 4259                         0.044816          False
# 4260                         0.044816          False
# 4261                         0.044816          False
# 4262                         0.044816          False
# 4263                         0.044816          False
# 4264                         0.060459          False
# 4265                         0.041034          False
# 4266                         0.070234          False
# 4267                         0.070234          False
# 4268                         0.070234          False
# 4269                         0.070234          False
# 4270                         0.070234          False
# 4271                         0.038464          False
# 4272                         0.040681          False
# 4273                         0.038464          False
# 4274                         0.038464          False
# ...                               ...            ...
# 8846                         0.038464          False
# 8847                         0.038464          False
# 8848                         0.038464          False
# 8849                         0.038464          False
# 8850                         0.038464          False
# 8851                         0.038464          False
# 8852                         0.038464          False
# 8853                         0.038464          False
# 8854                         0.041034          False
# 8855                         0.038464          False
# 8856                         0.038464          False
# 8857                         0.038464          False
# 8858                         0.038464          False
# 8859                         0.038464          False
# 8860                         0.038464          False
# 8861                         0.038464          False
# 8862                         0.038464          False
# 8863                         0.038464          False
# 8864                         0.038464          False
# 8865                         0.038464          False
# 8866                         0.038464          False
# 8867                         0.038464          False
# 8868                         0.038464          False
# 8869                         0.038464          False
# 8870                         0.038464          False
# 8871                         0.038464          False
# 8872                         0.038464          False
# 8873                         0.038464          False
# 8874                         0.038464          False
# address                           NaN           True
#
# [4631 rows x 14 columns]

# %%
read_fsq_df = pd.read_csv('fsq_calls.csv')
read_fsq_df.tail(10)
# df_top25['api_call_made'] = False
df_sliced = df_top25.iloc[4246:]
df_sliced.head()
# Out:
#                              address             categories            city  \
# 4246              950 State Route 36                    NaN         Hornell
# 4247               2900 Wendell Blvd  Fast Food Restaurants         Wendell
# 4248                718 Canton Rd NW                    NaN      Carrollton
# 4249  108 N Interstate 45 Service Rd                    NaN        Hutchins
# 4250                  10141 N 2nd St                    NaN  Machesney Park
#
#      country   latitude  longitude        name postalCode province  \
# 4246      US  42.345460  -77.66680  McDonald's      14843       NY
# 4247      US  35.792697  -78.37903  McDonald's      27591       NC
# 4248      US  40.582420  -81.09161  McDonald's      44615       OH
# 4249      US  32.649190  -96.70708  McDonald's      75141       TX
# 4250      US  42.366211  -89.03252  McDonald's      61115       IL
#
#      cleaned_name  is_tourist_province  rest_per_km2_province  \
# 4246    mcdonalds                  1.0               0.003998
# 4247    mcdonalds                  0.0               0.004455
# 4248    mcdonalds                  0.0               0.007758
# 4249    mcdonalds                  1.0               0.001632
# 4250    mcdonalds                  0.0               0.003971
#
#       rest_per_1000people_province  api_call_made
# 4246                      0.024972          False
# 4247                      0.054027          False
# 4248                      0.070234          False
# 4249                      0.038464          False
# 4250                      0.044816          False

# %%
print(len(df_top25.index))

# %%
def add_lat_long(lat_long, values):
    if type(lat_long) is not np.ndarray:
        lat_long = values
    else:
        lat_long = np.vstack((lat_long,values))
    return lat_long

def get_neighbours(each_):
    if each_['api_call_made']:
        return each_
    
    lat_long = None
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'school')
    print(each_venue, ' : collecting')
    if not (type(each_venue) is str):
        each_['schools'] = len(each_venue.index)
        lat_long = each_venue[['lat','lng']].values
    else:
        each_['schools'] = 0
        
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'university')
    if not (type(each_venue) is str):
        each_['university'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['university'] = 0
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'hospital')
    if not (type(each_venue) is str):
        each_['hospital'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['hospital'] = 0
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'park')
    if not (type(each_venue) is str):
        each_['park'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['park'] = 0
    
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'office')
    if not (type(each_venue) is str):
        each_['offices'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['offices'] = 0
    
        
    each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'mall')
    if not (type(each_venue) is str):
        each_['mall'] = len(each_venue.index)
        lat_long = add_lat_long(lat_long, each_venue[['lat','lng']].values)
    else:
        each_['mall'] = 0

    each_['all_lat_long'] = lat_long
    each_['api_call_made'] = True
    df_top25.at[each_.T.index[0], 'api_call_made'] = True
    each_ = pd.DataFrame(each_)
    each_.T.to_csv('fsq_calls.csv', index=True, sep=',',header=False, index_label=None, mode='a')
    return each_ 
# each_.to_csv('fsq_calls.csv', mode='a', header=False)

# df_il.reset_index()
df_sliced.apply(get_neighbours,axis=1)
# Out:
# {'meta': {'requestId': '5cee0ce74c1f6753b0345b70', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0ce7db04f52f6140ddd5', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0ce8db04f52f632a6f2d', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0ce99fb6b775bdbbaeac', 'code': 200}, 'response': {'venues': [{'name': 'Shawmut Park', 'categories': [{'name': 'Park', 'shortName': 'Park', 'pluralName': 'Parks', 'primary': True, 'id': '4bf58dd8d48988d163941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_'}}], 'location': {'distance': 355, 'country': 'United States', 'formattedAddress': ['1000 Shawmut Industrial Park', 'Hornell, NY 14843', 'United States'], 'address': '1000 Shawmut Industrial Park', 'lat': 42.34362763967076, 'labeledLatLngs': [{'lat': 42.34362763967076, 'label': 'display', 'lng': -77.67033661326056}], 'cc': 'US', 'state': 'NY', 'city': 'Hornell', 'lng': -77.67033661326056, 'postalCode': '14843'}, 'hasPerk': False, 'id': '4c9e126554c8a1cd23b4894b', 'referralId': 'v-1559104745'}, {'name': 'Michael C. Fucci Mermorial Park', 'categories': [{'name': 'Park', 'shortName': 'Park', 'pluralName': 'Parks', 'primary': True, 'id': '4bf58dd8d48988d163941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_'}}], 'location': {'distance': 316, 'formattedAddress': ['Hornell, NY', 'United States'], 'lat': 42.34479204491715, 'labeledLatLngs': [{'lat': 42.34479204491715, 'label': 'display', 'lng': -77.67054351751372}], 'country': 'United States', 'state': 'NY', 'city': 'Hornell', 'lng': -77.67054351751372, 'cc': 'US'}, 'hasPerk': False, 'id': '51853c89498ea97c4fce8755', 'referralId': 'v-1559104745'}, {'name': 'Hornell Skate Park', 'categories': [{'name': 'Skate Park', 'shortName': 'Skate Park', 'pluralName': 'Skate Parks', 'primary': True, 'id': '4bf58dd8d48988d167941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skate_park_'}}], 'location': {'distance': 366, 'formattedAddress': ['Hornell, NY', 'United States'], 'lat': 42.34342956542969, 'labeledLatLngs': [{'lat': 42.34342956542969, 'label': 'display', 'lng': -77.6703109741211}], 'country': 'United States', 'state': 'NY', 'city': 'Hornell', 'lng': -77.6703109741211, 'cc': 'US'}, 'hasPerk': False, 'id': '53418f77498ef9e00e690e19', 'referralId': 'v-1559104745'}]}}
# {'meta': {'requestId': '5cee0ceaf594df57e953a04a', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0ceaf594df57ef11b9d7', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0ceb6a6071493fb5eb72', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0cecf594df57ef11c2b9', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cee6a607149411eb808', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0ceedd57970e24b57770', 'code': 200}, 'response': {'venues': [{'name': 'Shawmut Park', 'categories': [{'name': 'Park', 'shortName': 'Park', 'pluralName': 'Parks', 'primary': True, 'id': '4bf58dd8d48988d163941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_'}}], 'location': {'distance': 355, 'country': 'United States', 'formattedAddress': ['1000 Shawmut Industrial Park', 'Hornell, NY 14843', 'United States'], 'address': '1000 Shawmut Industrial Park', 'lat': 42.34362763967076, 'labeledLatLngs': [{'lat': 42.34362763967076, 'label': 'display', 'lng': -77.67033661326056}], 'cc': 'US', 'state': 'NY', 'city': 'Hornell', 'lng': -77.67033661326056, 'postalCode': '14843'}, 'hasPerk': False, 'id': '4c9e126554c8a1cd23b4894b', 'referralId': 'v-1559104750'}, {'name': 'Michael C. Fucci Mermorial Park', 'categories': [{'name': 'Park', 'shortName': 'Park', 'pluralName': 'Parks', 'primary': True, 'id': '4bf58dd8d48988d163941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_'}}], 'location': {'distance': 316, 'formattedAddress': ['Hornell, NY', 'United States'], 'lat': 42.34479204491715, 'labeledLatLngs': [{'lat': 42.34479204491715, 'label': 'display', 'lng': -77.67054351751372}], 'country': 'United States', 'state': 'NY', 'city': 'Hornell', 'lng': -77.67054351751372, 'cc': 'US'}, 'hasPerk': False, 'id': '51853c89498ea97c4fce8755', 'referralId': 'v-1559104750'}, {'name': 'Hornell Skate Park', 'categories': [{'name': 'Skate Park', 'shortName': 'Skate Park', 'pluralName': 'Skate Parks', 'primary': True, 'id': '4bf58dd8d48988d167941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skate_park_'}}], 'location': {'distance': 366, 'formattedAddress': ['Hornell, NY', 'United States'], 'lat': 42.34342956542969, 'labeledLatLngs': [{'lat': 42.34342956542969, 'label': 'display', 'lng': -77.6703109741211}], 'country': 'United States', 'state': 'NY', 'city': 'Hornell', 'lng': -77.6703109741211, 'cc': 'US'}, 'hasPerk': False, 'id': '53418f77498ef9e00e690e19', 'referralId': 'v-1559104750'}]}}
# {'meta': {'requestId': '5cee0cef9fb6b7757f29e4d4', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cf06a607149411ec2ed', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cf1f594df57ee1babd7', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0cf2dd57970e24b586ab', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cf36a6071493fb60b6e', 'code': 200}, 'response': {'venues': [{'name': 'Neuse River Veterinary Hospital', 'categories': [{'name': 'Veterinarian', 'shortName': 'Veterinarians', 'pluralName': 'Veterinarians', 'primary': True, 'id': '4d954af4a243a5684765b473', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_'}}], 'location': {'distance': 252, 'country': 'United States', 'formattedAddress': ['2961 Wendell Blvd', 'Wendell, NC 27591', 'United States'], 'address': '2961 Wendell Blvd', 'lat': 35.7910832, 'labeledLatLngs': [{'lat': 35.7910832, 'label': 'display', 'lng': -78.3770672}], 'cc': 'US', 'state': 'NC', 'city': 'Wendell', 'lng': -78.3770672, 'postalCode': '27591'}, 'hasPerk': False, 'id': '4e4e996e52b1e893ad4ebf80', 'referralId': 'v-1559104755', 'venuePage': {'id': '167854204'}}]}}
# {'meta': {'requestId': '5cee0cf41ed21914c1eb3c5d', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cf59fb6b7757ef5ca25', 'code': 200}, 'response': {'venues': [{'name': 'US Post Office', 'categories': [{'name': 'Post Office', 'shortName': 'Post Office', 'pluralName': 'Post Offices', 'primary': True, 'id': '4bf58dd8d48988d172941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_'}}], 'location': {'distance': 270, 'country': 'United States', 'formattedAddress': ['40 Hanor Ln', 'Wendell, NC 27591', 'United States'], 'address': '40 Hanor Ln', 'lat': 35.79310414786513, 'labeledLatLngs': [{'lat': 35.79310414786513, 'label': 'display', 'lng': -78.37607527148558}], 'cc': 'US', 'state': 'NC', 'city': 'Wendell', 'lng': -78.37607527148558, 'postalCode': '27591'}, 'hasPerk': False, 'id': '4c228dc713c00f47e9b087de', 'referralId': 'v-1559104757'}]}}
# {'meta': {'requestId': '5cee0cf5f594df57ed0dcd8b', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cf66a607149411edcfe', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0cf7db04f52f632aafd8', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cf89fb6b775bdbbf005', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cf94434b92141d73d7f', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cfadd57970e24b5a92d', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cfadb04f52f5fbd4647', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cfb6a6071493e9c8793', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0cfc351e3d12869275e1', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cfddb04f52f5fbd517e', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cfe351e3d1288a7ca9c', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0cff1ed21914c1eb6db9', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d004c1f6753b1769883', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d019fb6b7758086722c', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0d021ed21914bfa14d5e', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d039fb6b775bdbc1f32', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d041ed21914bfa15642', 'code': 200}, 'response': {'venues': [{'name': 'Sport Clips Haircuts of Machesney Park', 'categories': [{'name': 'Salon / Barbershop', 'shortName': 'Salon / Barbershop', 'pluralName': 'Salons / Barbershops', 'primary': True, 'id': '4bf58dd8d48988d110951735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_'}}], 'location': {'distance': 169, 'country': 'United States', 'formattedAddress': ['1275 West Lane Road', 'Machesney Park, IL 61115', 'United States'], 'address': '1275 West Lane Road', 'lat': 42.3649566, 'labeledLatLngs': [{'lat': 42.3649566, 'label': 'display', 'lng': -89.0336883}], 'cc': 'US', 'state': 'IL', 'city': 'Machesney Park', 'lng': -89.0336883, 'postalCode': '61115'}, 'hasPerk': False, 'id': '4e459e64b0fb93df26fe74ee', 'referralId': 'v-1559104772'}, {'name': 'All About Eyes - Machesney Park', 'categories': [{'name': 'Optical Shop', 'shortName': 'Optical', 'pluralName': 'Optical Shops', 'primary': True, 'id': '4d954afda243a5684865b473', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_'}}], 'location': {'distance': 252, 'country': 'United States', 'formattedAddress': ['1419 W Lane Rd Ste B', 'Machesney Park, IL 61115', 'United States'], 'address': '1419 W Lane Rd Ste B', 'lat': 42.3651258, 'labeledLatLngs': [{'lat': 42.3651258, 'label': 'display', 'lng': -89.0298172}], 'cc': 'US', 'state': 'IL', 'city': 'Machesney Park', 'lng': -89.0298172, 'postalCode': '61115'}, 'hasPerk': False, 'id': '57640901cd10d3f25cd3026a', 'referralId': 'v-1559104772'}, {'name': 'Machesney Park Currency Exchange', 'categories': [{'name': 'Currency Exchange', 'shortName': 'Currency Exchange', 'pluralName': 'Currency Exchanges', 'primary': True, 'id': '5744ccdfe4b0c0459246b4be', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_'}}], 'location': {'formattedAddress': ['Hwy 173 (N. 2nd St.)', 'Machesney Park, IL 61115', 'United States'], 'address': 'Hwy 173', 'lat': 42.36742313, 'cc': 'US', 'distance': 140, 'crossStreet': 'N. 2nd St.', 'labeledLatLngs': [{'lat': 42.36742313, 'label': 'display', 'lng': -89.03299704}], 'country': 'United States', 'state': 'IL', 'city': 'Machesney Park', 'lng': -89.03299704, 'postalCode': '61115'}, 'hasPerk': False, 'id': '4e8cc57130f82b1224c5dbc0', 'referralId': 'v-1559104772'}, {'name': 'Machesney Park Family Dental', 'categories': [{'name': "Dentist's Office", 'shortName': "Dentist's Office", 'pluralName': "Dentist's Offices", 'primary': True, 'id': '4bf58dd8d48988d178941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_'}}], 'location': {'distance': 211, 'country': 'United States', 'formattedAddress': ['1411 W Lane Rd Ste B', 'Machesney Park, IL 61115', 'United States'], 'address': '1411 W Lane Rd Ste B', 'lat': 42.36499895884337, 'labeledLatLngs': [{'lat': 42.36499895884337, 'label': 'display', 'lng': -89.03053164482117}], 'cc': 'US', 'state': 'IL', 'city': 'Machesney Park', 'lng': -89.03053164482117, 'postalCode': '61115'}, 'hasPerk': False, 'id': '5877325e2a19820df963bdd0', 'referralId': 'v-1559104772'}, {'name': 'Park Motors Inc', 'categories': [{'name': 'Auto Dealership', 'shortName': 'Auto Dealer', 'pluralName': 'Auto Dealerships', 'primary': True, 'id': '4eb1c1623b7b52c0e1adc2ec', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_'}}], 'location': {'distance': 429, 'country': 'United States', 'formattedAddress': ['9728 N 2nd St', 'Machesney Park, IL 61115', 'United States'], 'address': '9728 N 2nd St', 'lat': 42.36480291894244, 'labeledLatLngs': [{'lat': 42.36480291894244, 'label': 'display', 'lng': -89.03738737106323}], 'cc': 'US', 'state': 'IL', 'city': 'Machesney Park', 'lng': -89.03738737106323, 'postalCode': '61115'}, 'hasPerk': False, 'id': '588605058d8e992976635616', 'referralId': 'v-1559104772'},  ...
# {'meta': {'requestId': '5cee0d059fb6b775bdbc293b', 'code': 200}, 'response': {'venues': [{'name': 'dentis office', 'categories': [], 'location': {'distance': 59, 'formattedAddress': ['Illinois', 'United States'], 'lat': 42.365809, 'labeledLatLngs': [{'lat': 42.365809, 'label': 'display', 'lng': -89.032989}], 'country': 'United States', 'state': 'Illinois', 'lng': -89.032989, 'cc': 'US'}, 'hasPerk': False, 'id': '4b869bcdf964a520f59131e3', 'referralId': 'v-1559104773'}]}}
# {'meta': {'requestId': '5cee0d069fb6b775bbea5cf4', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d07351e3d1283646314', 'code': 200}, 'response': {'venues': [{'name': 'Bronx Charter School-Children', 'categories': [{'name': 'School', 'shortName': 'School', 'pluralName': 'Schools', 'primary': True, 'id': '4bf58dd8d48988d13b941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 502, 'country': 'United States', 'formattedAddress': ['388 Willis Ave', 'Bronx, NY 10454', 'United States'], 'address': '388 Willis Ave', 'lat': 40.81257640946423, 'labeledLatLngs': [{'lat': 40.81257640946423, 'label': 'display', 'lng': -73.92006323520837}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.92006323520837, 'postalCode': '10454'}, 'hasPerk': False, 'id': '4da5962b93a01f42fac8fde9', 'referralId': 'v-1559104775'}, {'name': 'PS 1 Courtlandt School', 'categories': [{'name': 'School', 'shortName': 'School', 'pluralName': 'Schools', 'primary': True, 'id': '4bf58dd8d48988d13b941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 415, 'country': 'United States', 'formattedAddress': ['Bronx, NY 10451', 'United States'], 'lat': 40.81964415617261, 'labeledLatLngs': [{'lat': 40.81964415617261, 'label': 'display', 'lng': -73.91947447633902}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91947447633902, 'postalCode': '10451'}, 'hasPerk': False, 'id': '4dc40047d4c0ad9c0f62c0d7', 'referralId': 'v-1559104775'}, {'name': 'Immaculate Conception School', 'categories': [{'name': 'General College & University', 'shortName': 'Education', 'pluralName': 'General Colleges & Universities', 'primary': True, 'id': '4bf58dd8d48988d1a8941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_'}}], 'location': {'distance': 128, 'country': 'United States', 'formattedAddress': ['151street', 'Bronx, NY 10455', 'United States'], 'address': '151street', 'lat': 40.81757263648895, 'labeledLatLngs': [{'lat': 40.81757263648895, 'label': 'display', 'lng': -73.91722397850054}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91722397850054, 'postalCode': '10455'}, 'hasPerk': False, 'id': '4da7585804376c33686e47db', 'referralId': 'v-1559104775'}, {'name': 'Metropolitan Lighthouse Charter School', 'categories': [{'name': 'Elementary School', 'shortName': 'Elementary School', 'pluralName': 'Elementary Schools', 'primary': True, 'id': '4f4533804b9074f6e4fb0105', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 265, 'formattedAddress': ['Bronx, NY', 'United States'], 'lat': 40.81554515586798, 'labeledLatLngs': [{'lat': 40.81554515586798, 'label': 'display', 'lng': -73.91988783025357}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91988783025357, 'cc': 'US'}, 'hasPerk': False, 'id': '5270fd6f498e5a090b1248f8', 'referralId': 'v-1559104775'}, {'name': 'The Laboratory School of Finance & Technology', 'categories': [{'name': 'High School', 'shortName': 'High School', 'pluralName': 'High Schools', 'primary': True, 'id': '4bf58dd8d48988d13d941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'formattedAddress': ['360 E 145th St (145th St. & 3rd Ave.)', 'Bronx, NY 10454', 'United States'], 'address': '360 E 145th St', 'lat': 40.81301346717118, 'cc': 'US', 'distance': 468, 'crossStreet': '145th St. & 3rd Ave.', 'labeledLatLngs': [{'lat': 40.81301346717118, 'label': 'display', 'lng': -73.92019987106323}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.92019987106323, 'postalCode': '10454'}, 'hasPerk': False, 'id': '5221585d2fc6e3d976dca305', 'referralId': 'v-1559104775', 'venuePage': {'id': '76772977'}}, {'name': 'Hostos High School', 'categories': [{'name': 'High School', 'shortName': 'High School', 'pluralName': 'High Schools', 'primary': True, 'id': '4bf ...
#                                                  name  \
# 0                       Bronx Charter School-Children
# 1                              PS 1 Courtlandt School
# 2                        Immaculate Conception School
# 3              Metropolitan Lighthouse Charter School
# 4       The Laboratory School of Finance & Technology
# 5                                  Hostos High School
# 6                   PS 018 - John Peter Zenger School
# 7   Alfred E. Smith Career and Technical Education...
# 8                      South Bronx Preparatory School
# 9              Green Dot New York Charter High School
# 10                University Prep Charter High School
# 11                          PS 001x Courtlandt School
# 12                           Melrose school PS. MS 29
#
#                       categories             address  cc      city  \
# 0                         School      388 Willis Ave  US     Bronx
# 1                         School                 NaN  US     Bronx
# 2   General College & University           151street  US     Bronx
# 3              Elementary School                 NaN  US     Bronx
# 4                    High School      360 E 145th St  US     Bronx
# 5                    High School                 NaN  US     Bronx
# 6              Elementary School      502 Morris Ave  US     Bronx
# 7                    High School      333 E 151st St  US     Bronx
# 8                    High School      360 E 145th St  US     Bronx
# 9                    High School  600 Saint Anns Ave  US     Bronx
# 10                   High School  600 Saint Anns Ave  US     Bronx
# 11                        School      335 E 152nd St  US     Bronx
# 12                        School                 NaN  US  New York
#
#           country           crossStreet  distance  \
# 0   United States                   NaN       502
# 1   United States                   NaN       415
# 2   United States                   NaN       128
# 3   United States                   NaN       265
# 4   United States  145th St. & 3rd Ave.       468
# 5   United States                   NaN       412
# 6   United States                   NaN       464
# 7   United States                   NaN       362
# 8   United States           at 3rd Ave.       404
# 9   United States                   NaN       397
# 10  United States                   NaN       427
# 11  United States     Courtlandt Avenue       307
# 12  United States   758 Courtlandt Ave.       584
#
#                                      formattedAddress  \
# 0    [388 Willis Ave, Bronx, NY 10454, United States]
# 1                    [Bronx, NY 10451, United States]
# 2         [151street, Bronx, NY 10455, United States]
# 3                          [Bronx, NY, United States]
# 4   [360 E 145th St (145th St. & 3rd Ave.), Bronx,...
# 5                    [Bronx, NY 10455, United States]
# 6    [502 Morris Ave, Bronx, NY 10451, United States]
# 7    [333 E 151st St, Bronx, NY 10451, United States]
# 8   [360 E 145th St (at 3rd Ave.), Bronx, NY 10454...
# 9   [600 Saint Anns Ave, Bronx, NY 10455, United S...
# 10  [600 Saint Anns Ave, Bronx, NY 10455, United S...
# 11  [335 E 152nd St (Courtlandt Avenue), Bronx, NY...
# 12                [New York, NY 10451, United States]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lat': 40.81257640946423, 'label': 'display'...  40.812576 -73.920063
# 1   [{'lat': 40.81964415617261, 'label': 'display'...  40.819644 -73.919474
# 2   [{'lat': 40.81757263648895, 'label': 'display'...  40.817573 -73.917224
# 3   [{'lat': 40.81554515586798, 'label': 'display'...  40.815545 -73.919888
# 4   [{'lat': 40.81301346717118, 'label': 'display'...  40.813013 -73.920200
# 5   [{'lat': 40.815083924580634, 'label': 'display...  40.815084 -73.912401
# 6   [{'lat': 40.81639674335944, 'label': 'display'...  40.816397 -73.922477
# 7   [{'lat': 40.81870717446597, 'label': 'display'...  40.818707 -73.920043
# 8   [{'lat': 40.81377988052001, 'label': 'display'...  40.813780 -73.920242
# 9   [{'lat': 40.814815, 'label': 'display', 'lng':...  40.814815 -73.912767
# 10  [{'lat': 40.814975, 'label': 'display', 'lng':...  40.814975 -73.912272
# 11  [{'lat': 40.818031512816184, 'label': 'display...  40.818032 -73.919951
# 12  [{'lat': 40.821677780838804, 'label': 'display...  40.821678 -73.917267
#
#    postalCode state                        id search_q
# 0       10454    NY  4da5962b93a01f42fac8fde9   school
# 1       10451    NY  4dc40047d4c0ad9c0f62c0d7   school
# 2       10455    NY  4da7585804376c33686e47db   school
# 3         NaN    NY  5270fd6f498e5a090b1248f8   school
# 4       10454    NY  5221585d2fc6e3d976dca305   school
# 5       10455    NY  4f4b860fe4b0c132f40ac21b   school
# 6       10451    NY  521f865111d26a12b9324608   school
# 7       10451    NY  4c9e35ca0e9bb1f7e8ede45f   school
# 8       10454    NY  4baae7aef964a520308d3ae3   school
# 9       10455    NY  4d75109fe278f04d5fd15fb8   school
# 10      10455    NY  54ecc16a498e204a7ed13e21   school
# 11      10451    NY  4c862099d34ca143c8b94c80   school
# 12      10451    NY  4b4f5a54f964a520b80227e3   school    : collecting
# {'meta': {'requestId': '5cee0d084c1f6753b3b01055', 'code': 200}, 'response': {'venues': [{'name': 'University Prep Charter High School', 'categories': [{'name': 'High School', 'shortName': 'High School', 'pluralName': 'High Schools', 'primary': True, 'id': '4bf58dd8d48988d13d941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 427, 'country': 'United States', 'formattedAddress': ['600 Saint Anns Ave', 'Bronx, NY 10455', 'United States'], 'address': '600 Saint Anns Ave', 'lat': 40.814975, 'labeledLatLngs': [{'lat': 40.814975, 'label': 'display', 'lng': -73.912272}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.912272, 'postalCode': '10455'}, 'hasPerk': False, 'id': '54ecc16a498e204a7ed13e21', 'referralId': 'v-1559104776'}, {'name': 'University Heights HS', 'categories': [{'name': 'High School', 'shortName': 'High School', 'pluralName': 'High Schools', 'primary': True, 'id': '4bf58dd8d48988d13d941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 443, 'country': 'United States', 'formattedAddress': ['701 Saint Anns Ave', 'Bronx, NY 10455', 'United States'], 'address': '701 Saint Anns Ave', 'lat': 40.81624825643644, 'labeledLatLngs': [{'lat': 40.81624825643644, 'label': 'display', 'lng': -73.91170670401658}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91170670401658, 'postalCode': '10455'}, 'hasPerk': False, 'id': '4ea5deb17ee5bebc946e59c0', 'referralId': 'v-1559104776'}, {'name': 'Cornell University Cooperative Extension', 'categories': [{'name': 'General College & University', 'shortName': 'Education', 'pluralName': 'General Colleges & Universities', 'primary': True, 'id': '4bf58dd8d48988d1a8941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_'}}], 'location': {'distance': 182, 'formattedAddress': ['432 E. 149th Street', 'Bronx, NY', 'United States'], 'address': '432 E. 149th Street', 'lat': 40.81552278063581, 'labeledLatLngs': [{'lat': 40.81552278063581, 'label': 'display', 'lng': -73.91516865415437}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91516865415437, 'cc': 'US'}, 'hasPerk': False, 'id': '4c76a27b1b30a09326a6f209', 'referralId': 'v-1559104776'}]}}
# {'meta': {'requestId': '5cee0d091ed21914c048e6c1', 'code': 200}, 'response': {'venues': [{'name': 'Lincoln Hospital Emergency Room', 'categories': [{'name': 'Emergency Room', 'shortName': 'Emergency Room', 'pluralName': 'Emergency Rooms', 'primary': True, 'id': '4bf58dd8d48988d194941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_'}}], 'location': {'distance': 290, 'country': 'United States', 'formattedAddress': ['Bronx, NY 10451', 'United States'], 'lat': 40.817249982469306, 'labeledLatLngs': [{'lat': 40.817249982469306, 'label': 'display', 'lng': -73.92024377319797}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.92024377319797, 'postalCode': '10451'}, 'hasPerk': False, 'id': '50cce330e4b07c153f7a18a6', 'referralId': 'v-1559104777'}, {'name': 'Lincoln Hospital Pediatric Clinic, 1C2', 'categories': [{'name': "Doctor's Office", 'shortName': "Doctor's Office", 'pluralName': "Doctor's Offices", 'primary': True, 'id': '4bf58dd8d48988d177941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_'}}], 'location': {'distance': 577, 'formattedAddress': ['Bronx, NY', 'United States'], 'lat': 40.816574, 'labeledLatLngs': [{'lat': 40.816574, 'label': 'display', 'lng': -73.923814}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.923814, 'cc': 'US'}, 'hasPerk': False, 'id': '5a57cab116fa041f85487fbb', 'referralId': 'v-1559104777'}, {'name': 'Lincoln Hospital Blood Bank', 'categories': [{'name': 'Laboratory', 'shortName': 'Laboratory', 'pluralName': 'Laboratories', 'primary': True, 'id': '5744ccdfe4b0c0459246b4d6', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_'}}], 'location': {'distance': 561, 'formattedAddress': ['Bronx, NY', 'United States'], 'lat': 40.81653, 'labeledLatLngs': [{'lat': 40.81653, 'label': 'display', 'lng': -73.923635}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.923635, 'cc': 'US'}, 'hasPerk': False, 'id': '59ee4ed1a6031c1ebfa85fe8', 'referralId': 'v-1559104777'}, {'name': 'The Gift Shop at Lincoln Hospital', 'categories': [{'name': 'Snack Place', 'shortName': 'Snacks', 'pluralName': 'Snack Places', 'primary': True, 'id': '4bf58dd8d48988d1c7941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_'}}], 'location': {'distance': 569, 'formattedAddress': ['Bronx, NY', 'United States'], 'lat': 40.81657, 'labeledLatLngs': [{'lat': 40.81657, 'label': 'display', 'lng': -73.923722}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.923722, 'cc': 'US'}, 'hasPerk': False, 'id': '5ae77f3dfd16bb002c92e255', 'referralId': 'v-1559104777'}, {'name': 'Lincoln Hospital OHS', 'categories': [{'name': "Doctor's Office", 'shortName': "Doctor's Office", 'pluralName': "Doctor's Offices", 'primary': True, 'id': '4bf58dd8d48988d177941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_'}}], 'location': {'distance': 589, 'formattedAddress': ['Bronx, NY', 'United States'], 'lat': 40.816668, 'labeledLatLngs': [{'lat': 40.816668, 'label': 'display', 'lng': -73.923956}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.923956, 'cc': 'US'}, 'hasPerk': False, 'id': '5ae087f982a7504128a7904b', 'referralId': 'v-1559104777'}, {'name': 'Lincoln Hospital 5A OR#2', 'categories': [{'name': 'Hospital Ward', 'shortName': 'Hospital Ward', 'pluralName': 'Hospital Wards', 'primary': True, 'id': '58daa1558bbb0b01f18ec1f7', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_'}}], 'location': {'distance': 600, 'formattedAddress': ['Bronx, NY', 'United States'], 'lat': 40.816392, 'labeledLatLngs': [{'lat': 40.816392, 'label': 'display', 'lng': -73.924095}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.924095, 'cc': 'US'}, 'hasPerk': False ...
# {'meta': {'requestId': '5cee0d0a4c1f6753b034f4cc', 'code': 200}, 'response': {'venues': [{'name': 'Central Park Rehab', 'categories': [{'name': "Doctor's Office", 'shortName': "Doctor's Office", 'pluralName': "Doctor's Offices", 'primary': True, 'id': '4bf58dd8d48988d177941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_'}}], 'location': {'distance': 106, 'country': 'United States', 'formattedAddress': ['2825 3rd Ave, Bronx, NY 10455', 'Bronx, NY 10455', 'United States'], 'address': '2825 3rd Ave, Bronx, NY 10455', 'lat': 40.816070358319465, 'labeledLatLngs': [{'lat': 40.816070358319465, 'label': 'display', 'lng': -73.91813107004805}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91813107004805, 'postalCode': '10455'}, 'hasPerk': False, 'id': '4f58eee5e4b0882cd717c651', 'referralId': 'v-1559104778'}, {'name': 'St. Anne Park', 'categories': [], 'location': {'distance': 419, 'country': 'United States', 'formattedAddress': ['153 Street & 102 Avenue', 'Edmonton, NY 10455', 'United States'], 'address': '153 Street & 102 Avenue', 'lat': 40.8145124933953, 'labeledLatLngs': [{'lat': 40.8145124933953, 'label': 'display', 'lng': -73.91268271609181}], 'cc': 'US', 'state': 'NY', 'city': 'Edmonton', 'lng': -73.91268271609181, 'postalCode': '10455'}, 'hasPerk': False, 'id': '4b107694f964a520fc7023e3', 'referralId': 'v-1559104778'}, {'name': "Rubie's Skate Park", 'categories': [], 'location': {'distance': 539, 'country': 'United States', 'crossStreet': "St Ann's Ave", 'formattedAddress': ['Bronx, NY 10451', 'United States'], 'lat': 40.82033966666667, 'labeledLatLngs': [{'lat': 40.82033966666667, 'label': 'display', 'lng': -73.91316576666667}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91316576666667, 'postalCode': '10451'}, 'hasPerk': False, 'id': '4cd0611348b83704642df2de', 'referralId': 'v-1559104778'}, {'name': "St. Mary's Park Houses", 'categories': [{'name': 'Neighborhood', 'shortName': 'Neighborhood', 'pluralName': 'Neighborhoods', 'primary': True, 'id': '4f2a25ac4b909258e854f55f', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_'}}], 'location': {'distance': 593, 'formattedAddress': ['Bronx, NY', 'United States'], 'lat': 40.813207, 'labeledLatLngs': [{'lat': 40.813207, 'label': 'display', 'lng': -73.911361}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.911361, 'cc': 'US'}, 'hasPerk': False, 'id': '53150f51e4b0e72a36ec4fc5', 'referralId': 'v-1559104778'}, {'name': 'Parking Systems Plus Inc.', 'categories': [{'name': 'Parking', 'shortName': 'Parking', 'pluralName': 'Parking', 'primary': True, 'id': '4c38df4de52ce0d596b336e1', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_'}}], 'location': {'distance': 338, 'country': 'United States', 'formattedAddress': ['315 E 149th St', 'Bronx, NY 10451', 'United States'], 'address': '315 E 149th St', 'lat': 40.817372, 'labeledLatLngs': [{'lat': 40.817372, 'label': 'display', 'lng': -73.92079}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.92079, 'postalCode': '10451'}, 'hasPerk': False, 'id': '4c975dab6b35a143294a35dc', 'referralId': 'v-1559104778'}, {'name': 'Parking Violation', 'categories': [{'name': 'Courthouse', 'shortName': 'Courthouse', 'pluralName': 'Courthouses', 'primary': True, 'id': '4bf58dd8d48988d12b941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_courthouse_'}}], 'location': {'distance': 614, 'formattedAddress': ['New York', 'United States'], 'lat': 40.82105215339814, 'labeledLatLngs': [{'lat': 40.82105215339814, 'label': 'display', 'lng': -73.91296403631098}], 'country': 'United States', 'state': 'New York', 'lng': -73.91296403631098, 'cc': 'US'}, 'hasPerk': False, 'id': '4e837b8093ad6c49304179dc', 'referralId': 'v-1559104778'}]}}
# {'meta': {'requestId': '5cee0d0b6a60714939986148', 'code': 200}, 'response': {'venues': [{'name': 'USPS Post Office - Hub Station', 'categories': [{'name': 'Post Office', 'shortName': 'Post Office', 'pluralName': 'Post Offices', 'primary': True, 'id': '4bf58dd8d48988d172941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_'}}], 'location': {'distance': 429, 'country': 'United States', 'formattedAddress': ['633 Saint Anns Ave', 'Bronx, NY 10455', 'United States'], 'address': '633 Saint Anns Ave', 'lat': 40.81622065953991, 'labeledLatLngs': [{'lat': 40.81622065953991, 'label': 'display', 'lng': -73.91187193743173}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91187193743173, 'postalCode': '10455'}, 'hasPerk': False, 'id': '4bf29d4355c7c9b6ac476204', 'referralId': 'v-1559104779'}, {'name': 'Office Of Children And Family Services', 'categories': [{'name': 'Building', 'shortName': 'Building', 'pluralName': 'Buildings', 'primary': True, 'id': '4bf58dd8d48988d130941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_'}}], 'location': {'distance': 346, 'country': 'United States', 'formattedAddress': ['334 E 148th St, Bronx, NY 10451', 'Bronx, NY 10451', 'United States'], 'address': '334 E 148th St, Bronx, NY 10451', 'lat': 40.81587505789945, 'labeledLatLngs': [{'lat': 40.81587505789945, 'label': 'display', 'lng': -73.92101880799984}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.92101880799984, 'postalCode': '10451'}, 'hasPerk': False, 'id': '4f578920e4b0b1792ebce773', 'referralId': 'v-1559104779'}, {'name': 'Bronx Office', 'categories': [{'name': 'Office', 'shortName': 'Office', 'pluralName': 'Offices', 'primary': True, 'id': '4bf58dd8d48988d124941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_'}}], 'location': {'distance': 49, 'country': 'United States', 'formattedAddress': ['555 Bergen Ave', 'Bronx, NY 10455', 'United States'], 'address': '555 Bergen Ave', 'lat': 40.81618022410831, 'labeledLatLngs': [{'lat': 40.81618022410831, 'label': 'display', 'lng': -73.91648769378662}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.91648769378662, 'postalCode': '10455'}, 'hasPerk': False, 'id': '50dcbdc68055ba17b3d9c71d', 'referralId': 'v-1559104779'}, {'name': 'City Year Bronx Office', 'categories': [{'name': 'Non-Profit', 'shortName': 'Non-Profit', 'pluralName': 'Non-Profits', 'primary': True, 'id': '50328a8e91d4c4b30a586d6c', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_'}}], 'location': {'distance': 205, 'country': 'United States', 'formattedAddress': ['349 E 149th St', 'Bronx, NY 10451', 'United States'], 'address': '349 E 149th St', 'lat': 40.817215, 'labeledLatLngs': [{'lat': 40.817215, 'label': 'display', 'lng': -73.919174}], 'cc': 'US', 'state': 'NY', 'city': 'Bronx', 'lng': -73.919174, 'postalCode': '10451'}, 'hasPerk': False, 'id': '580df968d67c5cee14fc3229', 'referralId': 'v-1559104779'}, {'name': 'IH PL Bx Office', 'categories': [{'name': 'Office', 'shortName': 'Office', 'pluralName': 'Offices', 'primary': True, 'id': '4bf58dd8d48988d124941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_'}}], 'location': {'formattedAddress': ['522 Courtlandt Ave (148th Stree)', 'Bronx, NY 10451', 'United States'], 'address': '522 Courtlandt Ave', 'lat': 40.81614480258593, 'cc': 'US', 'distance': 365, 'crossStreet': '148th Stree', 'labeledLatLngs': [{'lat': 40.81614480258593, 'label': 'display', 'lng': -73.92128863420565}], 'country': 'United States', 'state': 'NY', 'city': 'Bronx', 'lng': -73.92128863420565, 'postalCode': '10451'}, 'hasPerk': False, 'id': '4ea5804f02d529c117e0738b', 'referralId': 'v-1559104779'}, {'name': 'Affinityplan Office', 'categories': [{'name': 'Building', 'shortName': 'Building', 'pluralName': 'Buildings', 'primary': True, 'id': '4bf58dd8d4898 ...
# {'meta': {'requestId': '5cee0d0c351e3d128692b921', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d0d351e3d1284b728dd', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0d0e4c1f6753b76ce367', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d0f9fb6b7758086aeb8', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d101ed21914c04903ca', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d101ed21914c1ebb993', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d114c1f6753b3b039bf', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d121ed21914bdf8c0e9', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0d131ed21914bb2908bf', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d141ed21914bdf8c7a6', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d15dd57970e200bba69', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d161ed21914bfa1a455', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d17351e3d1287141942', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d186a60714939989b8a', 'code': 200}, 'response': {'venues': [{'name': 'Red Bud Elementary School', 'categories': [{'name': 'Elementary School', 'shortName': 'Elementary School', 'pluralName': 'Elementary Schools', 'primary': True, 'id': '4f4533804b9074f6e4fb0105', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 369, 'country': 'United States', 'formattedAddress': ['200 W Field Dr', 'Red Bud, IL 62278', 'United States'], 'address': '200 W Field Dr', 'lat': 38.20156442324093, 'labeledLatLngs': [{'lat': 38.20156442324093, 'label': 'display', 'lng': -89.99629855155945}], 'cc': 'US', 'state': 'IL', 'city': 'Red Bud', 'lng': -89.99629855155945, 'postalCode': '62278'}, 'hasPerk': False, 'id': '4d825d2fcbef3704fef09add', 'referralId': 'v-1559104792'}, {'name': "St. John's Lutheran School", 'categories': [], 'location': {'distance': 727, 'country': 'United States', 'formattedAddress': ['104 E South 6th St', 'Red Bud, IL 62278', 'United States'], 'address': '104 E South 6th St', 'lat': 38.20537263, 'labeledLatLngs': [{'lat': 38.20537263, 'label': 'display', 'lng': -89.99344488}], 'cc': 'US', 'state': 'IL', 'city': 'Red Bud', 'lng': -89.99344488, 'postalCode': '62278'}, 'hasPerk': False, 'id': '4d8bd551b1252c0f5c56d3f0', 'referralId': 'v-1559104792'}]}}
#                          name         categories             address  cc  \
# 0   Red Bud Elementary School  Elementary School      200 W Field Dr  US
# 1  St. John's Lutheran School               None  104 E South 6th St  US
#
#       city        country  distance  \
# 0  Red Bud  United States       369
# 1  Red Bud  United States       727
#
#                                     formattedAddress  \
# 0  [200 W Field Dr, Red Bud, IL 62278, United Sta...
# 1  [104 E South 6th St, Red Bud, IL 62278, United...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lat': 38.20156442324093, 'label': 'display'...  38.201564 -89.996299
# 1  [{'lat': 38.20537263, 'label': 'display', 'lng...  38.205373 -89.993445
#
#   postalCode state                        id search_q
# 0      62278    IL  4d825d2fcbef3704fef09add   school
# 1      62278    IL  4d8bd551b1252c0f5c56d3f0   school    : collecting
# {'meta': {'requestId': '5cee0d194c1f6753b3b05ae5', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d1af594df57ed0e6e1e', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d1bf594df57ec3e1e84', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d1c6a607149411f83c3', 'code': 200}, 'response': {'venues': [{'name': 'Dr. Nancy Birner Office', 'categories': [{'name': "Doctor's Office", 'shortName': "Doctor's Office", 'pluralName': "Doctor's Offices", 'primary': True, 'id': '4bf58dd8d48988d177941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_'}}], 'location': {'distance': 343, 'country': 'United States', 'formattedAddress': ['Red Bud, IL 62278', 'United States'], 'lat': 38.197766, 'labeledLatLngs': [{'lat': 38.197766, 'label': 'display', 'lng': -89.990199}], 'cc': 'US', 'state': 'IL', 'city': 'Red Bud', 'lng': -89.990199, 'postalCode': '62278'}, 'hasPerk': False, 'id': '4f903c02e4b08140620dea14', 'referralId': 'v-1559104796'}]}}
# {'meta': {'requestId': '5cee0d1ddb04f52f6141c929', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d1e351e3d1288a855d6', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee0d1ff594df57ee1c7430', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d20db04f52f632b60e2', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d21351e3d1284b780b0', 'code': 200}, 'response': {'venues': [{'name': 'Breaks Interstate Park', 'categories': [], 'location': {'distance': 198, 'formattedAddress': ['Richlands, VA', 'United States'], 'lat': 37.0924483, 'labeledLatLngs': [{'lat': 37.0924483, 'label': 'display', 'lng': -81.8116462}], 'country': 'United States', 'state': 'VA', 'city': 'Richlands', 'lng': -81.8116462, 'cc': 'US'}, 'hasPerk': False, 'id': '5208e38411d2522d8e66d66c', 'referralId': 'v-1559104801'}]}}
# {'meta': {'requestId': '5cee0d221ed21914bb294790', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d23351e3d1286931dc2', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee0d23351e3d128364dfdf', 'code': 200}, 'response': {'venues': [{'name': 'Morton West High School', 'categories': [{'name': 'High School', 'shortName': 'High School', 'pluralName': 'High Schools', 'primary': True, 'id': '4bf58dd8d48988d13d941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'formattedAddress': ['2400 Home Ave (btwn Cermak Rd & Riverside Dr)', 'Berwyn, IL 60402', 'United States'], 'address': '2400 Home Ave', 'lat': 41.84712964041156, 'cc': 'US', 'distance': 405, 'crossStreet': 'btwn Cermak Rd & Riverside Dr', 'labeledLatLngs': [{'lat': 41.84712964041156, 'label': 'display', 'lng': -87.7999177792325}], 'country': 'United States', 'state': 'IL', 'city': 'Berwyn', 'lng': -87.7999177792325, 'postalCode': '60402'}, 'hasPerk': False, 'id': '4cf6f5bb71538cfa3dc4b82e', 'referralId': 'v-1559104803'}, {'name': 'M240 In SCHOOL SUSPENSION', 'categories': [{'name': 'High School', 'shortName': 'High School', 'pluralName': 'High Schools', 'primary': True, 'id': '4bf58dd8d48988d13d941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 463, 'country': 'United States', 'formattedAddress': ['Home Ave', 'Berwyn, IL 60402', 'United States'], 'address': 'Home Ave', 'lat': 41.84637969348185, 'labeledLatLngs': [{'lat': 41.84637969348185, 'label': 'display', 'lng': -87.80012904992944}], 'cc': 'US', 'state': 'IL', 'city': 'Berwyn', 'lng': -87.80012904992944, 'postalCode': '60402'}, 'hasPerk': False, 'id': '5141dfd5e4b0ffc7b8efdfab', 'referralId': 'v-1559104803'}]}}
#                         name   categories        address  cc    city  \
# 0    Morton West High School  High School  2400 Home Ave  US  Berwyn
# 1  M240 In SCHOOL SUSPENSION  High School       Home Ave  US  Berwyn
#
#          country                    crossStreet  distance  \
# 0  United States  btwn Cermak Rd & Riverside Dr       405
# 1  United States                            NaN       463
#
#                                     formattedAddress  \
# 0  [2400 Home Ave (btwn Cermak Rd & Riverside Dr)...
# 1        [Home Ave, Berwyn, IL 60402, United States]
#
#                                       labeledLatLngs       lat        lng  \
# 0  [{'lat': 41.84712964041156, 'label': 'display'...  41.84713 -87.799918
# 1  [{'lat': 41.84637969348185, 'label': 'display'...  41.84638 -87.800129
#
#   postalCode state                        id search_q
# 0      60402    IL  4cf6f5bb71538cfa3dc4b82e   school
# 1      60402    IL  5141dfd5e4b0ffc7b8efdfab   school    : collecting
# {'meta': {'requestId': '5cee0d244c1f6753b76d4704', 'code': 200}, 'response': {'venues': [{'name': "Rush University Children's Hospital North Riverside", 'categories': [{'name': 'Medical Center', 'shortName': 'Medical', 'pluralName': 'Medical Centers', 'primary': True, 'id': '4bf58dd8d48988d104941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_'}}], 'location': {'distance': 213, 'country': 'United States', 'formattedAddress': ['7222 W Cermak Rd Ste 718', 'North Riverside, IL 60546', 'United States'], 'address': '7222 W Cermak Rd Ste 718', 'lat': 41.85075900003282, 'labeledLatLngs': [{'lat': 41.85075900003282, 'label': 'display', 'lng': -87.80532538890844}], 'cc': 'US', 'state': 'IL', 'city': 'North Riverside', 'lng': -87.80532538890844, 'postalCode': '60546'}, 'hasPerk': False, 'id': '5a68ff63c8b2fb0754dc131d', 'referralId': 'v-1559104804'}]}}
# {'meta': {'requestId': '5cee0d26351e3d128364ea78', 'code': 200}, 'response': {'venues': [{'name': "Rush University Children's Hospital North Riverside", 'categories': [{'name': 'Medical Center', 'shortName': 'Medical', 'pluralName': 'Medical Centers', 'primary': True, 'id': '4bf58dd8d48988d104941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_'}}], 'location': {'distance': 213, 'country': 'United States', 'formattedAddress': ['7222 W Cermak Rd Ste 718', 'North Riverside, IL 60546', 'United States'], 'address': '7222 W Cermak Rd Ste 718', 'lat': 41.85075900003282, 'labeledLatLngs': [{'lat': 41.85075900003282, 'label': 'display', 'lng': -87.80532538890844}], 'cc': 'US', 'state': 'IL', 'city': 'North Riverside', 'lng': -87.80532538890844, 'postalCode': '60546'}, 'hasPerk': False, 'id': '5a68ff63c8b2fb0754dc131d', 'referralId': 'v-1559104806'}]}}
# ...
# {'meta': {'requestId': '5cee1074dd57970e23df5c51', 'code': 200}, 'response': {'venues': [{'name': 'Klopmeier Park', 'categories': [{'name': 'Park', 'shortName': 'Park', 'pluralName': 'Parks', 'primary': True, 'id': '4bf58dd8d48988d163941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_'}}], 'location': {'distance': 331, 'formattedAddress': ['Alton, IL', 'United States'], 'lat': 38.903365, 'labeledLatLngs': [{'lat': 38.903365, 'label': 'display', 'lng': -90.060352}], 'country': 'United States', 'state': 'IL', 'city': 'Alton', 'lng': -90.060352, 'cc': 'US'}, 'hasPerk': False, 'id': '519fb498498e3067c4c905ff', 'referralId': 'v-1559105652'}]}}
# {'meta': {'requestId': '5cee10751ed21914c1fa9967', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee10769fb6b7757e053db0', 'code': 200}, 'response': {'venues': [{'name': 'The Craft & Antique Mall', 'categories': [{'name': 'Antique Shop', 'shortName': 'Antiques', 'pluralName': 'Antique Shops', 'primary': True, 'id': '4bf58dd8d48988d116951735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_'}}], 'location': {'distance': 167, 'country': 'United States', 'formattedAddress': ['Bethalto, IL 62010', 'United States'], 'lat': 38.902801513671875, 'labeledLatLngs': [{'lat': 38.902801513671875, 'label': 'display', 'lng': -90.0575942993164}], 'cc': 'US', 'state': 'IL', 'city': 'Bethalto', 'lng': -90.0575942993164, 'postalCode': '62010'}, 'hasPerk': False, 'id': '4f7204b4e4b090ee3f1129cf', 'referralId': 'v-1559105654'}]}}
# {'meta': {'requestId': '5cee10779fb6b7758095b606', 'code': 200}, 'response': {'venues': [{'name': 'Parish School Of Performing Arts', 'categories': [{'name': 'Professional & Other Places', 'shortName': 'Professional', 'pluralName': 'Professional & Other Places', 'primary': True, 'id': '4d4b7105d754a06375d81259', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_'}}], 'location': {'distance': 475, 'formattedAddress': ['Jerseyville, IL', 'United States'], 'lat': 39.114209, 'labeledLatLngs': [{'lat': 39.114209, 'label': 'display', 'lng': -90.321732}], 'country': 'United States', 'state': 'IL', 'city': 'Jerseyville', 'lng': -90.321732, 'cc': 'US'}, 'hasPerk': False, 'id': '4e8b883c775bb28051ea0351', 'referralId': 'v-1559105655'}]}}
#                                name                   categories  cc  \
# 0  Parish School Of Performing Arts  Professional & Other Places  US
#
#           city        country  distance                  formattedAddress  \
# 0  Jerseyville  United States       475  [Jerseyville, IL, United States]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lat': 39.114209, 'label': 'display', 'lng':...  39.114209 -90.321732
#
#   state                        id search_q
# 0    IL  4e8b883c775bb28051ea0351   school    : collecting
# {'meta': {'requestId': '5cee10789fb6b7757f397979', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee10794434b921407385a2', 'code': 200}, 'response': {'venues': [{'name': 'Jersey Calhoun Veterinary Hospital', 'categories': [{'name': 'Veterinarian', 'shortName': 'Veterinarians', 'pluralName': 'Veterinarians', 'primary': True, 'id': '4d954af4a243a5684765b473', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_'}}], 'location': {'distance': 415, 'formattedAddress': ['Jerseyville, IL', 'United States'], 'lat': 39.107200622558594, 'labeledLatLngs': [{'lat': 39.107200622558594, 'label': 'display', 'lng': -90.3167953491211}], 'country': 'United States', 'state': 'IL', 'city': 'Jerseyville', 'lng': -90.3167953491211, 'cc': 'US'}, 'hasPerk': False, 'id': '51b9d650498e42b756dd8a15', 'referralId': 'v-1559105657'}]}}
# {'meta': {'requestId': '5cee107adb04f52f633a27df', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee107b351e3d1288b725fa', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee107c4434b921558e6d75', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee107ddb04f52f6150a678', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee107e6a60714939a792b4', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee107fdb04f52f5fccc709', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee1080351e3d1288b73cc5', 'code': 200}, 'response': {'venues': [{'name': 'Springtown Park', 'categories': [{'name': 'Playground', 'shortName': 'Playground', 'pluralName': 'Playgrounds', 'primary': True, 'id': '4bf58dd8d48988d1e7941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_'}}], 'location': {'distance': 253, 'country': 'United States', 'formattedAddress': ['301-307 Martin Ave', 'Springtown, TX 76082', 'United States'], 'address': '301-307 Martin Ave', 'lat': 32.9646723414805, 'labeledLatLngs': [{'lat': 32.9646723414805, 'label': 'display', 'lng': -97.67671445792146}], 'cc': 'US', 'state': 'TX', 'city': 'Springtown', 'lng': -97.67671445792146, 'postalCode': '76082'}, 'hasPerk': False, 'id': '4d3dc5446b3d236a4abf6c64', 'referralId': 'v-1559105664'}, {'name': 'Outback RV Park', 'categories': [{'name': 'RV Park', 'shortName': 'RV Park', 'pluralName': 'RV Parks', 'primary': True, 'id': '52f2ab2ebcbc57f1066b8b53', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_'}}], 'location': {'distance': 353, 'country': 'United States', 'formattedAddress': ['2520 E Highway 199', 'Springtown, TX 76082', 'United States'], 'address': '2520 E Highway 199', 'lat': 32.96, 'labeledLatLngs': [{'lat': 32.96, 'label': 'display', 'lng': -97.68}], 'cc': 'US', 'state': 'TX', 'city': 'Springtown', 'lng': -97.68, 'postalCode': '76082'}, 'hasPerk': False, 'id': '595ec80d2f97ec37ca666d38', 'referralId': 'v-1559105664'}]}}
# {'meta': {'requestId': '5cee10814c1f6753b77c18a3', 'code': 200}, 'response': {'venues': [{'name': 'US Post Office', 'categories': [{'name': 'Post Office', 'shortName': 'Post Office', 'pluralName': 'Post Offices', 'primary': True, 'id': '4bf58dd8d48988d172941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_'}}], 'location': {'distance': 200, 'country': 'United States', 'formattedAddress': ['Springtown, TX 76082', 'United States'], 'lat': 32.96132531859129, 'labeledLatLngs': [{'lat': 32.96132531859129, 'label': 'display', 'lng': -97.67946594002781}], 'cc': 'US', 'state': 'TX', 'city': 'Springtown', 'lng': -97.67946594002781, 'postalCode': '76082'}, 'hasPerk': False, 'id': '4bccf5a5fb84c9b69269213e', 'referralId': 'v-1559105665'}]}}
# {'meta': {'requestId': '5cee10824434b9217e2ffc23', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee1083351e3d1284c66c84', 'code': 200}, 'response': {'venues': [{'name': 'Mifflinburg Intermediate School', 'categories': [{'name': 'College Gym', 'shortName': 'Gym', 'pluralName': 'College Gyms', 'primary': True, 'id': '4bf58dd8d48988d1b2941735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_'}}], 'location': {'distance': 624, 'country': 'United States', 'formattedAddress': ['Mifflinburg, PA 17844', 'United States'], 'lat': 40.92017321731703, 'labeledLatLngs': [{'lat': 40.92017321731703, 'label': 'display', 'lng': -77.02848380345092}], 'cc': 'US', 'state': 'PA', 'city': 'Mifflinburg', 'lng': -77.02848380345092, 'postalCode': '17844'}, 'hasPerk': False, 'id': '4d84a3de8de9721ec3c03451', 'referralId': 'v-1559105667'}, {'name': 'Mifflinburg Elementary School', 'categories': [{'name': 'Elementary School', 'shortName': 'Elementary School', 'pluralName': 'Elementary Schools', 'primary': True, 'id': '4f4533804b9074f6e4fb0105', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'formattedAddress': ['Shipton Street (Mable)', 'Mifflinburg, PA 17844', 'United States'], 'address': 'Shipton Street', 'lat': 40.92006989188113, 'cc': 'US', 'distance': 412, 'crossStreet': 'Mable', 'labeledLatLngs': [{'lat': 40.92006989188113, 'label': 'display', 'lng': -77.03118841744207}], 'country': 'United States', 'state': 'PA', 'city': 'Mifflinburg', 'lng': -77.03118841744207, 'postalCode': '17844'}, 'hasPerk': False, 'id': '4c547ab5fd2ea593f2eb2a2a', 'referralId': 'v-1559105667'}, {'name': 'Mifflinburg Middle School', 'categories': [{'name': 'Middle School', 'shortName': 'Middle School', 'pluralName': 'Middle Schools', 'primary': True, 'id': '4f4533814b9074f6e4fb0106', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_'}}], 'location': {'distance': 594, 'country': 'United States', 'formattedAddress': ['178 Maple St', 'Mifflinburg, PA 17844', 'United States'], 'address': '178 Maple St', 'lat': 40.9213473246561, 'labeledLatLngs': [{'lat': 40.9213473246561, 'label': 'display', 'lng': -77.0286075085285}], 'cc': 'US', 'state': 'PA', 'city': 'Mifflinburg', 'lng': -77.0286075085285, 'postalCode': '17844'}, 'hasPerk': False, 'id': '4dd69bfbd1647fcf3e35c45b', 'referralId': 'v-1559105667'}, {'name': 'Soccer Fields At Mifflinburg Schools', 'categories': [{'name': 'Soccer Field', 'shortName': 'Soccer Field', 'pluralName': 'Soccer Fields', 'primary': True, 'id': '4cce455aebf7b749d5e191f5', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_'}}], 'location': {'distance': 423, 'formattedAddress': ['Mifflinburg, PA', 'United States'], 'lat': 40.92194339436187, 'labeledLatLngs': [{'lat': 40.92194339436187, 'label': 'display', 'lng': -77.03065986977226}], 'country': 'United States', 'state': 'PA', 'city': 'Mifflinburg', 'lng': -77.03065986977226, 'cc': 'US'}, 'hasPerk': False, 'id': '4dd7bd1bfa76ad96d12b6759', 'referralId': 'v-1559105667'}]}}
#                                    name         categories         address  \
# 0       Mifflinburg Intermediate School        College Gym             NaN
# 1         Mifflinburg Elementary School  Elementary School  Shipton Street
# 2             Mifflinburg Middle School      Middle School    178 Maple St
# 3  Soccer Fields At Mifflinburg Schools       Soccer Field             NaN
#
#    cc         city        country crossStreet  distance  \
# 0  US  Mifflinburg  United States         NaN       624
# 1  US  Mifflinburg  United States       Mable       412
# 2  US  Mifflinburg  United States         NaN       594
# 3  US  Mifflinburg  United States         NaN       423
#
#                                     formattedAddress  \
# 0             [Mifflinburg, PA 17844, United States]
# 1  [Shipton Street (Mable), Mifflinburg, PA 17844...
# 2  [178 Maple St, Mifflinburg, PA 17844, United S...
# 3                   [Mifflinburg, PA, United States]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lat': 40.92017321731703, 'label': 'display'...  40.920173 -77.028484
# 1  [{'lat': 40.92006989188113, 'label': 'display'...  40.920070 -77.031188
# 2  [{'lat': 40.9213473246561, 'label': 'display',...  40.921347 -77.028608
# 3  [{'lat': 40.92194339436187, 'label': 'display'...  40.921943 -77.030660
#
#   postalCode state                        id search_q
# 0      17844    PA  4d84a3de8de9721ec3c03451   school
# 1      17844    PA  4c547ab5fd2ea593f2eb2a2a   school
# 2      17844    PA  4dd69bfbd1647fcf3e35c45b   school
# 3        NaN    PA  4dd7bd1bfa76ad96d12b6759   school    : collecting
# {'meta': {'requestId': '5cee1084db04f52f661c79db', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee1085f594df57ed1d7d31', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee1086351e3d1287233d63', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee10874434b9216993912b', 'code': 200}, 'response': {'venues': [{'name': 'A+ Office Supply', 'categories': [{'name': 'Paper / Office Supplies Store', 'shortName': 'Office Supplies', 'pluralName': 'Paper / Office Supplies Stores', 'primary': True, 'id': '4bf58dd8d48988d121951735', 'icon': {'suffix': '.png', 'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_'}}], 'location': {'distance': 88, 'country': 'United States', 'formattedAddress': ['Mifflinburg, PA 17844', 'United States'], 'lat': 40.92220100452771, 'labeledLatLngs': [{'lat': 40.92220100452771, 'label': 'display', 'lng': -77.03633320230183}], 'cc': 'US', 'state': 'PA', 'city': 'Mifflinburg', 'lng': -77.03633320230183, 'postalCode': '17844'}, 'hasPerk': False, 'id': '4ee23c5e30f87dc0a6ad123d', 'referralId': 'v-1559105671'}]}}
# {'meta': {'requestId': '5cee1088dd57970e201af0f8', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee1089db04f52f5fccf218', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee108a1ed21914bb3835db', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee108b9fb6b77580960b85', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee108c6a6071493fc5e34d', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee108df594df57ed1d9e82', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee108e4c1f6753b1863c5d', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee108f1ed21914c058569c', 'code': 200}, 'response': {'venues': []}}
# No Venues Available  : collecting
# {'meta': {'requestId': '5cee1090db04f52f633a8596', 'code': 200}, 'response': {'venues': []}}
# {'meta': {'requestId': '5cee10901ed21914be292e39', 'errorDetail': 'Quota exceeded', 'errorType': 'quota_exceeded', 'code': 429}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-2db93fb4097c> in <module>()
#      65
#      66 # df_il.reset_index()
# ---> 67 df_sliced.apply(get_neighbours,axis=1)
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/anaconda2/envs/ml/lib/python3.5/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-22-2db93fb4097c> in get_neighbours(each_)
#      27         each_['university'] = 0
#      28
# ---> 29     each_venue = fsq.get_venue_search(each_['latitude'], each_['longitude'],'hospital')
#      30     if not (type(each_venue) is str):
#      31         each_['hospital'] = len(each_venue.index)
#
# <ipython-input-21-624a002b10f0> in get_venue_search(self, latitude, longitude, search_query, radius)
#      32         results = requests.get(url).json()
#      33         print(results)
# ---> 34         venues = results['response']['venues']
#      35         if not len(venues):
#      36             dataframe_filtered = 'No Venues Available'
#
# KeyError: ('venues', 'occurred at index 4403')

# %%
df_top25.shape

# %%
whut = fsq.get_venue_search(35.5573,-80.8611,'school')
not type(whut) is str

# %%
# 'burgerbasket': Int64Index([2430], dtype='int64'),
#  'burgerfi': Int64Index([7949], dtype='int64'),
#  'burgerhouse': Int64Index([8288], dtype='int64'),
#  'burgerking': Int64Index([ 3356, 19830,  3358, 12296, 12297,  3359,  3357,  3355, 18579,
#                546,
#              ...
#              11838, 14261, 11836,  7923, 10708, 15594, 19498, 19496, 10685,
#              11274],
#             dtype='int64', length=1987),
#  'burgerkingpopeyes': Int64Index([5950], dtype='int64'),
#  'burgerkingsalou': Int64Index([17684], dtype='int64'),
#  'burgerkingæ': Int64Index([9107], dtype='int64'),
#  'burgerslanding': Int64Index([14335], dtype='int64'),
#  'burgertime': Int64Index([12093], dtype='int64'),
#  'burgerville': Int64Index([19340], dtype='int64'),
#  'burgervilleusa'
fuzz.partial_ratio('aw', 'awallamericanfood')

# %%
with_all_data = pd.read_csv('fsq_calls.csv')
# with_all_data.set_index('province', inplace=True)

# %%
with_all_data_grpby = with_all_data.groupby('province')
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 9
with_all_data_grpby.get_group('VA').\
groupby('cleaned_name').sum().plot(kind='bar', x='cleaned_name', y = ['schools','university','hospital','park','offices','mall'])

# %%
with_all_data_grpby.head()

# %%
pd.concat([fg, pd.DataFrame([[5,6]],columns=['a','b'])],ignore_index=1)

# %%
df_top25.iloc[106]
